# %% [markdown]
# # Geração de Regras Nebulosas a partir de exemplos

# %% [markdown]
# [<img src="files/cc.png" width=100 height=40>](https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode)
# Autores: Leonardo Ferreira (leauferreira@gmail.com) e Petrônio Silva (petronio.candido@gmail.com)
#
#
#
# * [Resumo dos artigos](https://www.overleaf.com/read/hqxnrtmtvygh)
#
# * [Apresentação](https://www.overleaf.com/read/hnhzmgfgbndv)
#
# ##Índice
#
# 1. [Parte I - Código Fonte](#Parte-I---Código-Fonte)
#   1. [Importações Comuns](#Importações-Comuns)
#   2. [Métodos Auxiliares](#Métodos-Auxiliares)
#   3. [Métodos Principais](#Métodos-Principais)
# 2. [Parte II - Aplicações exemplo](#Parte-II---Aplicações-exemplo)
#   1. [Aplicação I - Aproximação de funções](#Aplicação-I---Aproximação-de-funções)
#   2. [Aplicação II - Controle de veículos](#Aplicação-II---Controle-de-veículos)
#   3. [Aplicação III - Predição de Séries Temporais](#Aplicação-III---Predição-de-Séries-Temporais)

# %% [markdown]
# # Parte I - Código Fonte

# %% [markdown]
# ## Importações Comuns

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from pandas import DataFrame

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Métodos Auxiliares

# %%
# Gera o nome do conjunto
def conj_nome(n, cont):
    if cont < n: 
        return 'S' + str(n - cont)
    elif cont == n:
        return 'CE'
    else:
        return 'B' + str(cont - n)

#Função de pertinência triangular
def triangular(a,b,c,xx):
        if(xx < a):
            return float(0)
        elif(xx >= a and xx < b):
            return float((xx-a)/(b-a))
        elif(xx >= b and xx <= c):
            return float((c-xx)/(c-b))
        else: 
            return float(0)

#Gera uma chave única a partir do antecedente da regra
def antecedente(dados,colunas,regra):
    key = ''
    for c in range(colunas - 1):
        col = dados.columns[c]
        key += regra[col]
    return key


#Imprime uma base de regras em formato amigável
def print_rule(regras,atributo_out):
    for regra in regras:
        out = ''
        for atr in regra.keys():
            if atr == atributo_out or atr == 'grau':
                continue
                
            if len(out) > 0:
                out += ' E '           

            out += atr + ' é ' + regra[atr]

        out = 'SE ' + out + ' ENTÃO ' + atributo_out + ' é ' + regra[atributo_out] + ' com grau ' + str(regra['grau'])
        print(out)
   
#Plota o gráfico dos conjuntos 2D
def plot_conj2D(x,y,conjuntos,nomes):
    
    minx = min(x)
    maxx = max(x)
    incx = (maxx - minx)/20
    miny = min(y)
    maxy = max(y)
    incy = (maxy - miny)/20
    
    plt.scatter(x,y)
    labels = []
    x = []
    for subconj in conjuntos[nomes[0]].keys():
        vals = conjuntos[nomes[0]][subconj]
        x.append(vals[1])
        labels.append(subconj)
        plt.axvline(vals[1],label=subconj)
        plt.plot([vals[0], vals[1], vals[2]],[miny,miny+incy,miny])
    
    plt.xticks(x, labels, rotation='vertical')
        
    labels = []
    y = []
    for subconj in conjuntos[nomes[1]].keys():
        vals = conjuntos[nomes[1]][subconj]
        y.append(vals[1])
        labels.append(subconj)
        plt.axhline(vals[1],label=subconj)
        plt.plot([minx,minx+incx,minx],[vals[0], vals[1], vals[2]])
        
    plt.yticks(y, labels, rotation='horizontal')

    plt.xlabel(nomes[0])
    plt.ylabel(nomes[1])

def plot_conj3D(x,y,z,conjuntos,nomes):
    
    fig = plt.figure()
    ax = Axes3D(fig)
    
    minx = min(x)
    maxx = max(x)
    incx = (maxx - minx)/20
    miny = min(y)
    maxy = max(y)
    incy = (maxy - miny)/20
    minz = min(z)
    maxz = max(z)
    incz = (maxz - minz)/20
    
    ax.scatter3D(x,y,z)
    labels = []
    x = []
    for subconj in conjuntos[nomes[0]].keys():
        vals = conjuntos[nomes[0]][subconj]
        x.append(vals[1])
        labels.append(subconj)
        #ax.axvline(vals[1],label=subconj,zdir='x')
        ax.plot([vals[0], vals[1], vals[2]],[miny,miny+incy,miny],zs=0,zdir='x')
    
    plt.xticks(x, labels, rotation='vertical')
        
    labels = []
    y = []
    for subconj in conjuntos[nomes[1]].keys():
        vals = conjuntos[nomes[1]][subconj]
        y.append(vals[1])
        labels.append(subconj)
        #ax.axhline(vals[1],label=subconj,zdir='y')
        #ax.plot([minx,minx+incx,minx],[vals[0], vals[1], vals[2]],zdir='y')
        
    plt.yticks(y, labels, rotation='horizontal')
    
    labels = []
    z = []
    for subconj in conjuntos[nomes[2]].keys():
        vals = conjuntos[nomes[2]][subconj]
        z.append(vals[1])
        labels.append(subconj)
        #ax.axhline(vals[1],label=subconj,zdir='z')
        #ax.plot([minz,minz+incz,minz],[vals[0], vals[1], vals[2]],zdir='z')
        
    print(labels)
        
    ax.set_zticks(z, labels)

    plt.xlabel(nomes[0])
    plt.ylabel(nomes[1])
    ax.set_zlabel(nomes[2])

# %% [markdown]
# ## Métodos Principais

# %%
def fuzzy_rule(dados,particoes):
    
    retorno = []
    linhas,colunas = dados.shape
    
    # ETAPA 1 - Particionamento do Espaço
    
    conjuntos = dict()
    
    for c in range(0,colunas):
        col = dados.columns[c]
        ma = max(dados[col])
        mi = min(dados[col])
        k = 2*particoes[c] + 1
        tam = (ma - mi)/k
        tam2 = tam/2
        subconjunto = dict()
        cont = 0
        for part in np.arange(mi,ma,tam):
            subconjunto[conj_nome(particoes[c],cont)] = [part - tam2, part + tam2, part + tam + tam2]
            cont += 1
        conjuntos[dados.columns[c]] = subconjunto
        
    #return conjuntos
    
    # ETAPA 2 - Regras
    
    # ETAPA 2.1 - Pertinência dos conjuntos
    
    pertinencias = []
    
    for inst in range(0,linhas):
        instperts = dict()
        for c in range(colunas):
            col = dados.columns[c]
            conj = conjuntos[col]
            perts = dict()
            for subconj in conj.keys():
                val = conj[subconj]
                tmp = triangular(val[0],val[1],val[2],dados[col][inst])
                perts[subconj] = tmp
            instperts[col] = perts
        pertinencias.append(instperts)
        
    #return pertinencias

    # ETAPA 2.1 - Regras a partir das pertinências
    
    regras = []
    
    for inst in range(linhas):
        instregra = dict()
        for c in range(colunas):
            col = dados.columns[c]
            conj = conjuntos[col]
            maxp = 0
            maxc = ''
            for subconj in conj.keys():
                if pertinencias[inst][col][subconj] > maxp:   #Escolhe o subconj com maior pertinência
                    maxp = pertinencias[inst][col][subconj]
                    maxc = subconj
            instregra[col] = maxc
        regras.append(instregra)
        
    #return regras

    # ETAPA 3 - Graus das regras
    
    # ETAPA 3.1 - Cálculo dos graus das regras
    inst = 0
    for regra in regras:
        grau = 1.0
        for c in range(colunas-1):
            col = dados.columns[c]
            grau = grau * pertinencias[inst][col][regra[col]]
        inst += 1
            
        regra['grau'] = grau
        
    # ETAPA 3.2 - Escolha das regras de maior grau
    nregras = dict()
    for regra in regras:
        ant = antecedente(dados,colunas,regra)
        if ant in nregras:
            if nregras[ant]['grau'] < regra['grau']:
                nregras[ant] = regra
        else:
            nregras[ant] = regra
            
    regras = []
    for kreg in nregras.keys():
        regra = nregras[kreg]
        regras.append(regra)
    
    retorno = []
    retorno.append(conjuntos)
    retorno.append(regras)
    
    return retorno

def defuzzy_rule(instancia,atributos_in,atributo_out,conjuntos,regras):
    
    #Etapa 5: Deffuzificação
    
    ativacoes = []
    centroides = []
    for regra in regras:
        ativ_regra = 1
        for atr in atributos_in:
            subconj = regra[atr]
            conj = conjuntos[atr][subconj]
            ativ = triangular(conj[0],conj[1],conj[2],instancia[atr])
            ativ_regra *= ativ
        centroides.append(conjuntos[atributo_out][regra[atributo_out]][1])
        ativacoes.append(ativ_regra)
        
    centroides_ponderadas = sum([float(centroides[k])*float(ativacoes[k]) for k in range(len(regras))])
    ativacoes = sum([float(ativacoes[k]) for k in range(len(regras))])
    
    return centroides_ponderadas / ativacoes

# %% [markdown]
# # Parte II - Aplicações exemplo

# %% [markdown]
# ## Aplicação I - Aproximação de funções

# %% [markdown]
# ##Função I - $y = x^2$

# %%
# Prepara o conjunto de treinamento

df = DataFrame([float(xx) for xx in np.arange(-1,1,0.1)],columns=['x'])
df['y'] = [xx*xx for xx in df['x']]
plot(df['x'],df['y'])

# %%
#Extrai os conjuntos e as regras 

conj,reg = fuzzy_rule(df,[20,20])

plot_conj2D(df['x'],df['y'],conj,['x','y'])
print_rule(reg2,'y')
# Out:
# SE x é S18 ENTÃO y é S9 com grau 0.657894736842
# SE x é B2 ENTÃO y é S30 com grau 0.605263157895
# SE x é S8 ENTÃO y é S25 com grau 0.973684210526
# SE x é S2 ENTÃO y é S30 com grau 0.605263157895
# SE x é S11 ENTÃO y é S21 com grau 0.763157894737
# SE x é B24 ENTÃO y é S1 com grau 0.921052631579
# SE x é B30 ENTÃO y é B19 com grau 0.5
# SE x é S30 ENTÃO y é B30 com grau 0.5
# SE x é S5 ENTÃO y é S28 com grau 0.815789473684
# SE x é S14 ENTÃO y é S15 com grau 0.552631578947
# SE x é B5 ENTÃO y é S30 com grau 0.815789473684
# SE x é B14 ENTÃO y é S21 com grau 0.552631578947
# SE x é S21 ENTÃO y é S1 com grau 0.868421052632
# SE x é S27 ENTÃO y é B19 com grau 0.710526315789
# SE x é S24 ENTÃO y é B9 com grau 0.921052631579
# SE x é B11 ENTÃO y é S25 com grau 0.763157894737
# SE x é B21 ENTÃO y é S9 com grau 0.868421052632
# SE x é B27 ENTÃO y é B9 com grau 0.710526315789
# SE x é B8 ENTÃO y é S28 com grau 0.973684210526
# SE x é B18 ENTÃO y é S15 com grau 0.657894736842

# %%
# Testa a aproximação

zz = []
for k in df['x']:
    zz.append(defuzzy_rule({'x':k},['x'],'y',conj,reg))
plot(df['x'],zz)

# %% [markdown]
# ##Função II - $y = \frac{sen(x)}{x}$

# %%
def sinc(xx):
    return math.sin(xx)/xx

# %%
# Prepara o conjunto de treinamento

df2 = DataFrame(np.arange(0.1,2*math.pi,0.1),columns=['x'])
df2['y'] = [float(sinc(xx)) for xx in df2['x']]
plot(df2['x'],df2['y'])

# %%
#Extrai os conjuntos e as regras 

conj2,reg2 = fuzzy_rule(df2,[30,30])

print_rule(reg2,'y')
plot_conj2D(df2['x'],df2['y'],conj2,['x','y'])
# Out:
# SE x é S9 ENTÃO y é S1 com grau 0.5
# SE x é S8 ENTÃO y é S3 com grau 0.5
# SE x é S3 ENTÃO y é S14 com grau 0.5
# SE x é S2 ENTÃO y é S17 com grau 0.5
# SE x é S7 ENTÃO y é S8 com grau 0.5
# SE x é S5 ENTÃO y é S10 com grau 0.5
# SE x é S16 ENTÃO y é B12 com grau 0.5
# SE x é B16 ENTÃO y é S30 com grau 0.5
# SE x é B17 ENTÃO y é S30 com grau 0.5
# SE x é B14 ENTÃO y é S30 com grau 0.5
# SE x é B15 ENTÃO y é S30 com grau 0.5
# SE x é B12 ENTÃO y é S30 com grau 0.5
# SE x é B13 ENTÃO y é S30 com grau 0.5
# SE x é B10 ENTÃO y é S30 com grau 0.5
# SE x é B18 ENTÃO y é S29 com grau 0.5
# SE x é S19 ENTÃO y é B18 com grau 0.5
# SE x é S18 ENTÃO y é B16 com grau 0.5
# SE x é S13 ENTÃO y é B5 com grau 0.5
# SE x é S11 ENTÃO y é B3 com grau 0.5
# SE x é S10 ENTÃO y é B1 com grau 0.5
# SE x é S17 ENTÃO y é B14 com grau 0.5
# SE x é S30 ENTÃO y é B30 com grau 0.5
# SE x é S15 ENTÃO y é B10 com grau 0.5
# SE x é S14 ENTÃO y é B8 com grau 0.5
# SE x é B30 ENTÃO y é S21 com grau 0.5
# SE x é CE ENTÃO y é S19 com grau 0.5
# SE x é S22 ENTÃO y é B23 com grau 0.5
# SE x é S23 ENTÃO y é B24 com grau 0.5
# SE x é S20 ENTÃO y é B21 com grau 0.5
# SE x é S27 ENTÃO y é B29 com grau 0.5
# SE x é S24 ENTÃO y é B25 com grau 0.5
# SE x é S25 ENTÃO y é B27 com grau 0.5
# SE x é S28 ENTÃO y é B30 com grau 0.5
# SE x é S4 ENTÃO y é S12 com grau 0.5
# SE x é B29 ENTÃO y é S22 com grau 0.5
# SE x é B28 ENTÃO y é S23 com grau 0.5
# SE x é B27 ENTÃO y é S24 com grau 0.5
# SE x é B26 ENTÃO y é S24 com grau 0.5
# SE x é B25 ENTÃO y é S25 com grau 0.5
# SE x é B24 ENTÃO y é S26 com grau 0.5
# SE x é B23 ENTÃO y é S27 com grau 0.5
# SE x é B22 ENTÃO y é S27 com grau 0.5
# SE x é B21 ENTÃO y é S28 com grau 0.5
# SE x é B20 ENTÃO y é S29 com grau 0.5
# SE x é B5 ENTÃO y é S26 com grau 0.5
# SE x é B6 ENTÃO y é S27 com grau 0.5
# SE x é B7 ENTÃO y é S28 com grau 0.5
# SE x é B1 ENTÃO y é S21 com grau 0.5
# SE x é B2 ENTÃO y é S22 com grau 0.5
# SE x é B3 ENTÃO y é S25 com grau 0.5
# SE x é B8 ENTÃO y é S28 com grau 0.5

# %%
# Testa a aproximação

zz = []
for k in df2['x']:
    zz.append(defuzzy_rule({'x':k},['x'],'y',conj2,reg2))
plot(df2['x'],zz)

# %% [markdown]
# ## Função III - $z = \frac{sen(x+y)}{x+y}$

# %%
# Prepara o conjunto de treinamento

df4 = DataFrame([[0,0,0]],columns=['x','y','z'])
X = []
Y = []
Z = []
for x in np.arange(-2*math.pi,2*math.pi,0.1):
    tmpX = []
    tmpY = []
    tmpZ = []
    for y in np.arange(-2*math.pi,2*math.pi,0.1):
        z = sinc(x+y)
        df4 = df4.append(DataFrame([[x,y,z]],columns=['x','y','z']))
        
        tmpX.append(x)
        tmpY.append(y)
        tmpZ.append(z)
        
    X.append(tmpX)
    Y.append(tmpY)
    Z.append(tmpZ)
    
df4.index = range(0,len(df4['x']))

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X, Y, Z)

# %%
conj4,reg4 = fuzzy_rule(df4,[3,3,3])

#print_rule(reg4,'z')
plot_conj3D(df4['x'],df4['y'],df4['z'],conj4,['x','y','z'])
# Out:
# ['S3', 'S2', 'S1', 'CE', 'B1', 'B2', 'B3']

# %%
ZZ = []
for x in np.arange(-2*math.pi,2*math.pi,0.1):
    tmpZ = []
    for y in np.arange(-2*math.pi,2*math.pi,0.1):
        
        z = defuzzy_rule({'x':x, 'y': y},['x','y'],'z',conj4,reg4)
        
        tmpZ.append(z)
        
    ZZ.append(tmpZ)

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X, Y, ZZ)

# %% [markdown]
# ## Aplicação II - Controle de veículos

# %%
table1 =[[1.0, 0.0, -19],
         [1.95,9.37,-17.95],
         [2.88,18.23,-16.9],
         [3.79, 26.59, -15.85],
         [4.65, 34.44, -14.80],
         [5.45, 41.78, -13.74],
         [6.18,48.60, -12.7],
         [7.48, 54.91,-11.65],
         [7.99,60.71,-10.6],
         [8.72,65.99,-9.55],
         [9.01,70.75,-8.5],
         [9.28,74.98,-7.45],
         [9.46, 78.70,-6.4],
         [9.59,81.90,-5.34],
         [9.72,84.57,-4.3],
         [9.81, 86.72,-3.25],
         [9.88,88.34,-2.2],
         [9.91,89.44,0.0]
]

# %%
table4 = [[7.0,0.0,-40.0],
          [7.76, 18.75,-38.5],
          [8.51,36.88,-37.0],
          [9.15,54.4,-35.5],
          [9.62,71.28,-34.0],
          [9.88,87.51,-3.0],
          [9.93,89.9,0]    
]

# %%
table10= [[13.0,180.0,40.0],
          [12.23,161.25,38.5],
          [11.49,143.11,37.0],
          [10.85,125.60,35.5],
          [10.38,108.72,34.0],
          [10.11,92.49,5.50],
          [10.08,98.80,0.0]
]

# %%
df5 = DataFrame(table1,columns=['x','phi','theta'])
df5 = df5.append(DataFrame(table4,columns=['x','phi','theta']))
df5 = df5.append(DataFrame(table10,columns=['x','phi','theta']))
df5.index = range(len(df5['x']))

# %%
conj5,reg5 = fuzzy_rule(df5,[5,5,5])
print_rule(reg5,'theta')
plot_conj2D(df5['x'],df5['phi'],conj5,['x','phi'])
# Out:
# SE x é B5 E phi é B5 ENTÃO theta é B5 com grau 0.25
# SE x é S2 E phi é S3 ENTÃO theta é S2 com grau 0.511447222222
# SE x é B3 E phi é B1 ENTÃO theta é B5 com grau 0.771826666667
# SE x é B5 E phi é B4 ENTÃO theta é B5 com grau 0.512899305556
# SE x é B4 E phi é B2 ENTÃO theta é B5 com grau 0.436268518519
# SE x é B4 E phi é B3 ENTÃO theta é B5 com grau 0.667005509259
# SE x é S4 E phi é S4 ENTÃO theta é S2 com grau 0.476916481481
# SE x é CE E phi é S5 ENTÃO theta é S5 com grau 0.5
# SE x é B1 E phi é S4 ENTÃO theta é S5 com grau 0.449930555556
# SE x é CE E phi é S2 ENTÃO theta é S2 com grau 0.479142222222
# SE x é S5 E phi é S5 ENTÃO theta é S2 com grau 0.583482175926
# SE x é B3 E phi é CE ENTÃO theta é B1 com grau 0.721364861111
# SE x é S1 E phi é S3 ENTÃO theta é S2 com grau 0.54834212963
# SE x é S3 E phi é S4 ENTÃO theta é S2 com grau 0.824739861111
# SE x é B2 E phi é S1 ENTÃO theta é S1 com grau 0.835278888889
# SE x é B1 E phi é S2 ENTÃO theta é S1 com grau 0.716874583333
# SE x é B2 E phi é S2 ENTÃO theta é S5 com grau 0.800398148148
# SE x é B2 E phi é CE ENTÃO theta é S1 com grau 0.338537777778
# SE x é B1 E phi é S3 ENTÃO theta é S5 com grau 0.464201481481

# %% [markdown]
# O método abaixo implementa a cinética do veículo, calcundo $x_{t+1}$ e $\phi_{t+_1}$ a partir do estado atual $(x_t, \phi_t)$ e $\theta$:
#
# $$
# x_{t+1} = x_t + cos(\phi_t+\theta_t) + sen(\theta_t)sen(\phi_t) \\
# \phi_{t+1} = \phi_t - sen^{-1}(\frac{2sen(\theta_t)}{b})
# $$

# %%
def calcula_cinetica(xx,phix,thetax,bx):
    
    pr = math.radians(phix)
    tr = math.radians(thetax)
    
    xtmp = xx + math.cos(pr + tr) + math.sin(tr)*math.sin(pr)
    
    phitmp = phix - math.degrees(math.asin(2*math.sin(tr)/bx))
    
    ret = [xtmp, phitmp]
    return ret

# %%
xt = 1.0
phit = 0.0
xf = 10.0
phif = 90.0
x = []
u = []
y = []
v = []
yy = 20
ax = plt.axes()
while yy < 50 and abs(xf - xt) > 0.1:
    x.append(xt)
    y.append(yy)
    thetat = defuzzy_rule({'x':xt, 'phi': phit},['x','phi'],'theta',conj5,reg5)
    xtn, phit = calcula_cinetica(xt,phit,thetat,4)
    ax.arrow(xt, yy, xtn-xt-0.1, -0.8,length_includes_head=True,head_width=0.2)
    yy -= 1    
    xt = xtn
    
scatter(x,y)

# %% [markdown]
# ## Aplicação III - Predição de Séries Temporais

# %% [markdown]
# A série temporal caótica de Mackey-Glass é gerada pela equação:
# $$
# \frac{dx(t)}{dt} = \beta\frac{ x(t - \tau)}{1 + x(t - \tau)^k} - \gamma x(t)
# $$

# %%
def mackey_glass_ts(n,tau, beta, gamma,k):
    xret = [rnd.random() for k in range(tau)]
    for t in range(tau-1,n):
        xret.append( beta*((xret[t - tau]) / (1 + math.pow(xret[t - tau],k))) - gamma*xret[t] )
    return xret

# %%
ts = mackey_glass_ts(500,50,0.9,0.5,10)
plot(ts)

# %%
def cria_dataframe(timeserie,m):
    labels = []
    dados = []
    
    for m1 in range(m,-1,-1):
        labels.append('t'+str(m1))
        
    for count in range(m + 1,len(timeserie)):
        tmp = [0 for xx in range(0,m+1)]
        for m1 in range(0,m+1):
            tmp[m1] = timeserie[count - m-m1]
        #print(tmp)
        dados.append(tmp)
        
    dfts = DataFrame(dados,columns=labels)
    dfts.index = range(len(dfts['t0']))
    
    return dfts

# %%
df_ts = cria_dataframe(ts,9)
df_ts.head()
# Out:
#          t9        t8        t7        t6        t5        t4        t3  \
# 0  0.263794  0.408388  0.610243  0.203173 -0.728609  0.744110 -0.703714
# 1  0.404699  0.263794  0.408388  0.610243  0.203173 -0.728609  0.744110
# 2  0.434034  0.404699  0.263794  0.408388  0.610243  0.203173 -0.728609
# 3  0.960403  0.434034  0.404699  0.263794  0.408388  0.610243  0.203173
# 4  0.077111  0.960403  0.434034  0.404699  0.263794  0.408388  0.610243
#
#          t2        t1        t0
# 0  0.849273 -0.746180  0.022517
# 1 -0.703714  0.849273 -0.746180
# 2  0.744110 -0.703714  0.849273
# 3 -0.728609  0.744110 -0.703714
# 4  0.203173 -0.728609  0.744110

# %%
particoes = [10 for xx in range(10)]
conj6,reg6 = fuzzy_rule(df_ts,particoes)
print_rule(reg6,'t0')
# Out:
# SE t8 é B3 E t9 é B4 E t6 é B5 E t7 é B3 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.124012001992
# SE t8 é S1 E t9 é B6 E t6 é CE E t7 é B6 E t4 é B1 E t5 é B6 E t2 é S1 E t3 é B5 E t1 é B6 ENTÃO t0 é CE com grau 0.0418005505155
# SE t8 é B4 E t9 é B4 E t6 é B5 E t7 é B3 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B5 E t1 é B4 ENTÃO t0 é B3 com grau 0.0995694041669
# SE t8 é B4 E t9 é B1 E t6 é B3 E t7 é B2 E t4 é B2 E t5 é B3 E t2 é B2 E t3 é B3 E t1 é B5 ENTÃO t0 é B1 com grau 0.101582522826
# SE t8 é B2 E t9 é B3 E t6 é B2 E t7 é B5 E t4 é B3 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B2 ENTÃO t0 é B4 com grau 0.079608409318
# SE t8 é B1 E t9 é B5 E t6 é B1 E t7 é B4 E t4 é B2 E t5 é B4 E t2 é B1 E t3 é B5 E t1 é B2 ENTÃO t0 é B4 com grau 0.0399398382293
# SE t8 é B3 E t9 é B4 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0832842235303
# SE t8 é B5 E t9 é B2 E t6 é B3 E t7 é B2 E t4 é B2 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B2 com grau 0.0959192696298
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B5 E t2 é B4 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.131994563762
# SE t8 é CE E t9 é B4 E t6 é B1 E t7 é B5 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B1 E t1 é B2 ENTÃO t0 é B3 com grau 0.0807776706142
# SE t8 é B5 E t9 é B1 E t6 é B5 E t7 é B2 E t4 é B3 E t5 é B2 E t2 é B5 E t3 é B2 E t1 é CE ENTÃO t0 é B5 com grau 0.124941648982
# SE t8 é B4 E t9 é B2 E t6 é B5 E t7 é B1 E t4 é B5 E t5 é B2 E t2 é B5 E t3 é B1 E t1 é B1 ENTÃO t0 é B5 com grau 0.0747713781195
# SE t8 é B2 E t9 é B5 E t6 é B4 E t7 é B2 E t4 é B4 E t5 é B2 E t2 é B6 E t3 é B1 E t1 é S1 ENTÃO t0 é B6 com grau 0.0509945449598
# SE t8 é B4 E t9 é B4 E t6 é B5 E t7 é B3 E t4 é B3 E t5 é B5 E t2 é B5 E t3 é B4 E t1 é B4 ENTÃO t0 é B4 com grau 0.069706050603
# SE t8 é B2 E t9 é B3 E t6 é B2 E t7 é B5 E t4 é B2 E t5 é B3 E t2 é B2 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.0281279101985
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B1 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.062887402253
# SE t8 é B2 E t9 é B4 E t6 é B1 E t7 é B3 E t4 é CE E t5 é B6 E t2 é B1 E t3 é B5 E t1 é B4 ENTÃO t0 é B1 com grau 0.0577649919505
# SE t8 é B2 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B5 E t5 é B2 E t2 é B3 E t3 é B2 E t1 é B2 ENTÃO t0 é B4 com grau 0.0108975993674
# SE t8 é CE E t9 é B6 E t6 é CE E t7 é B6 E t4 é CE E t5 é B5 E t2 é B2 E t3 é B4 E t1 é B3 ENTÃO t0 é B1 com grau 0.0298731173039
# SE t8 é CE E t9 é B4 E t6 é CE E t7 é B6 E t4 é CE E t5 é B6 E t2 é CE E t3 é B5 E t1 é B4 ENTÃO t0 é B2 com grau 0.0381786457801
# SE t8 é B5 E t9 é B1 E t6 é B4 E t7 é B2 E t4 é B4 E t5 é B1 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B4 com grau 0.0245823771528
# SE t8 é B6 E t9 é CE E t6 é B6 E t7 é CE E t4 é B5 E t5 é CE E t2 é B4 E t3 é CE E t1 é B2 ENTÃO t0 é B3 com grau 0.036235151887
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B4 E t1 é B3 ENTÃO t0 é B5 com grau 0.0216666407612
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B2 E t1 é B2 ENTÃO t0 é B3 com grau 0.0627644844817
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B3 E t4 é B5 E t5 é B1 E t2 é B4 E t3 é B2 E t1 é B2 ENTÃO t0 é B4 com grau 0.0212548137141
# SE t8 é B4 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B5 E t3 é B1 E t1 é B1 ENTÃO t0 é B5 com grau 0.0736323835776
# SE t8 é B4 E t9 é B5 E t6 é B3 E t7 é B4 E t4 é B4 E t5 é B4 E t2 é B1 E t3 é B3 E t1 é B5 ENTÃO t0 é B1 com grau 0.0711196054311
# SE t8 é B3 E t9 é B3 E t6 é B2 E t7 é B4 E t4 é B2 E t5 é B4 E t2 é B4 E t3 é B4 E t1 é B2 ENTÃO t0 é B5 com grau 0.0192863672986
# SE t8 é B2 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0601242624819
# SE t8 é CE E t9 é B4 E t6 é B1 E t7 é B5 E t4 é B2 E t5 é B5 E t2 é B2 E t3 é B3 E t1 é B3 ENTÃO t0 é B2 com grau 0.161413792837
# SE t8 é B4 E t9 é B2 E t6 é B5 E t7 é B1 E t4 é B3 E t5 é B2 E t2 é CE E t3 é B5 E t1 é B5 ENTÃO t0 é B2 com grau 0.0518472212967
# SE t8 é B3 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B3 E t1 é B1 ENTÃO t0 é B4 com grau 0.0589947077155
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.0202843784498
# SE t8 é B5 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B5 E t1 é B3 ENTÃO t0 é B4 com grau 0.130527683255
# SE t8 é B2 E t9 é B5 E t6 é B2 E t7 é B4 E t4 é B2 E t5 é B4 E t2 é B4 E t3 é B2 E t1 é B1 ENTÃO t0 é B4 com grau 0.0404760067037
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B2 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B5 com grau 0.140797934918
# SE t8 é B1 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B1 E t3 é B4 E t1 é B5 ENTÃO t0 é B2 com grau 0.0287150153912
# SE t8 é B4 E t9 é B3 E t6 é B6 E t7 é CE E t4 é B6 E t5 é S1 E t2 é B4 E t3 é CE E t1 é B1 ENTÃO t0 é B4 com grau 0.124619408792
# SE t8 é B3 E t9 é B5 E t6 é B5 E t7 é B4 E t4 é B4 E t5 é B4 E t2 é B3 E t3 é B5 E t1 é B4 ENTÃO t0 é B5 com grau 0.101863672561
# SE t8 é B1 E t9 é B4 E t6 é B2 E t7 é B4 E t4 é B1 E t5 é B5 E t2 é B4 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.0571827317564
# SE t8 é B4 E t9 é B4 E t6 é B3 E t7 é B5 E t4 é B5 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B4 ENTÃO t0 é B4 com grau 0.0286364302773
# SE t8 é B1 E t9 é B4 E t6 é CE E t7 é B6 E t4 é S1 E t5 é B5 E t2 é B4 E t3 é B4 E t1 é B1 ENTÃO t0 é B3 com grau 0.0879524518368
# SE t8 é CE E t9 é B5 E t6 é B2 E t7 é B4 E t4 é B1 E t5 é B3 E t2 é CE E t3 é B6 E t1 é B5 ENTÃO t0 é B1 com grau 0.0445667013973
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B5 E t4 é B3 E t5 é B4 E t2 é B5 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.134171879696
# SE t8 é B10 E t9 é CE E t6 é B3 E t7 é S10 E t4 é B4 E t5 é B2 E t2 é B4 E t3 é S1 E t1 é S1 ENTÃO t0 é B5 com grau 0.0472504058897
# SE t8 é B2 E t9 é B3 E t6 é B3 E t7 é B4 E t4 é B2 E t5 é B3 E t2 é B2 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.0783138437296
# SE t8 é B1 E t9 é B5 E t6 é B1 E t7 é B5 E t4 é B1 E t5 é B4 E t2 é B2 E t3 é B4 E t1 é B5 ENTÃO t0 é B1 com grau 0.033549263073
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B1 E t4 é B2 E t5 é B3 E t2 é CE E t3 é B4 E t1 é B5 ENTÃO t0 é B1 com grau 0.0707699693771
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B2 E t1 é B2 ENTÃO t0 é B4 com grau 0.0429997740164
# SE t8 é B5 E t9 é B1 E t6 é B4 E t7 é B1 E t4 é B2 E t5 é B3 E t2 é B1 E t3 é B4 E t1 é B3 ENTÃO t0 é B5 com grau 0.0489919498296
# SE t8 é B4 E t9 é B2 E t6 é B5 E t7 é B1 E t4 é B3 E t5 é B1 E t2 é B4 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.0288303711291
# SE t8 é B2 E t9 é B2 E t6 é CE E t7 é B5 E t4 é B2 E t5 é B5 E t2 é B3 E t3 é B2 E t1 é B4 ENTÃO t0 é B1 com grau 0.0820619325368
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B2 com grau 0.0608545556977
# SE t8 é B3 E t9 é B4 E t6 é B2 E t7 é B3 E t4 é B2 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B3 ENTÃO t0 é B2 com grau 0.146506393243
# SE t8 é B3 E t9 é B4 E t6 é B4 E t7 é B2 E t4 é B5 E t5 é B1 E t2 é B3 E t3 é B1 E t1 é B2 ENTÃO t0 é B4 com grau 0.0529172944788
# SE t8 é B5 E t9 é B3 E t6 é B3 E t7 é B5 E t4 é B5 E t5 é B4 E t2 é B4 E t3 é B4 E t1 é B5 ENTÃO t0 é B3 com grau 0.100312616616
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B5 ENTÃO t0 é B4 com grau 0.121287586612
# SE t8 é B2 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B3 E t1 é B2 ENTÃO t0 é B4 com grau 0.114759015835
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B1 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é CE ENTÃO t0 é B10 com grau 0.038778931121
# SE t8 é B2 E t9 é B5 E t6 é B2 E t7 é B3 E t4 é B2 E t5 é B3 E t2 é B1 E t3 é B5 E t1 é B2 ENTÃO t0 é B4 com grau 0.150102507001
# SE t8 é B5 E t9 é B2 E t6 é B5 E t7 é CE E t4 é B3 E t5 é B1 E t2 é CE E t3 é B4 E t1 é B6 ENTÃO t0 é S1 com grau 0.129606335967
# SE t8 é B5 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.103511490156
# SE t8 é B4 E t9 é B2 E t6 é B4 E t7 é S1 E t4 é B5 E t5 é S1 E t2 é B4 E t3 é B2 E t1 é B1 ENTÃO t0 é B3 com grau 0.0435005223412
# SE t8 é B5 E t9 é CE E t6 é B3 E t7 é B1 E t4 é CE E t5 é B4 E t2 é S1 E t3 é B6 E t1 é B6 ENTÃO t0 é CE com grau 0.0995292167835
# SE t8 é B2 E t9 é B4 E t6 é B2 E t7 é B3 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B1 com grau 0.175478562151
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B4 E t4 é B4 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.0714507435067
# SE t8 é B5 E t9 é B1 E t6 é B3 E t7 é B1 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B1 com grau 0.0532477721677
# SE t8 é B3 E t9 é B2 E t6 é B2 E t7 é B4 E t4 é B2 E t5 é B4 E t2 é B1 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.0411306335265
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B1 E t1 é B3 ENTÃO t0 é B3 com grau 0.0817441678015
# SE t8 é B5 E t9 é B1 E t6 é B4 E t7 é B1 E t4 é B4 E t5 é B1 E t2 é B5 E t3 é B2 E t1 é B1 ENTÃO t0 é B2 com grau 0.0326220941607
# SE t8 é B1 E t9 é B6 E t6 é B2 E t7 é B4 E t4 é B3 E t5 é B2 E t2 é B4 E t3 é B2 E t1 é B1 ENTÃO t0 é B6 com grau 0.0279603586211
# SE t8 é B1 E t9 é B4 E t6 é B2 E t7 é B3 E t4 é CE E t5 é B4 E t2 é B1 E t3 é B5 E t1 é B3 ENTÃO t0 é B4 com grau 0.46780856337
# SE t8 é B3 E t9 é S10 E t6 é B4 E t7 é B2 E t4 é B4 E t5 é S1 E t2 é B5 E t3 é S1 E t1 é B2 ENTÃO t0 é B4 com grau 0.0228807537445
# SE t8 é B3 E t9 é B1 E t6 é B4 E t7 é B2 E t4 é B5 E t5 é CE E t2 é B3 E t3 é B1 E t1 é B4 ENTÃO t0 é CE com grau 0.40720220662
# SE t8 é B4 E t9 é B2 E t6 é B4 E t7 é B2 E t4 é B4 E t5 é B1 E t2 é B2 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0127615689055
# SE t8 é B5 E t9 é CE E t6 é B2 E t7 é B2 E t4 é B1 E t5 é B5 E t2 é B2 E t3 é B5 E t1 é B4 ENTÃO t0 é B1 com grau 0.0193786379803
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.058749268438
# SE t8 é B3 E t9 é B1 E t6 é B4 E t7 é B2 E t4 é CE E t5 é B4 E t2 é CE E t3 é B6 E t1 é B6 ENTÃO t0 é CE com grau 0.134577052818
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B2 E t5 é B4 E t2 é B1 E t3 é B5 E t1 é B4 ENTÃO t0 é B2 com grau 0.0615603700238
# SE t8 é B1 E t9 é B5 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B2 E t3 é B2 E t1 é B5 ENTÃO t0 é CE com grau 0.0857951516167
# SE t8 é B2 E t9 é B3 E t6 é CE E t7 é B4 E t4 é B1 E t5 é B5 E t2 é B2 E t3 é B5 E t1 é B3 ENTÃO t0 é B2 com grau 0.189899455857
# SE t8 é B3 E t9 é B3 E t6 é B2 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B5 ENTÃO t0 é B3 com grau 0.0325866534951
# SE t8 é B1 E t9 é B3 E t6 é CE E t7 é B6 E t4 é B2 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B1 ENTÃO t0 é B4 com grau 0.0648321390317
# SE t8 é B1 E t9 é B3 E t6 é B1 E t7 é B6 E t4 é B2 E t5 é B4 E t2 é B3 E t3 é B2 E t1 é B2 ENTÃO t0 é B4 com grau 0.0243850517828
# SE t8 é B1 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B4 E t5 é B2 E t2 é B5 E t3 é B2 E t1 é CE ENTÃO t0 é B6 com grau 0.060692190835
# SE t8 é B2 E t9 é B3 E t6 é S1 E t7 é B4 E t4 é S1 E t5 é B4 E t2 é B2 E t3 é B5 E t1 é B4 ENTÃO t0 é B1 com grau 0.0380483621451
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B4 com grau 0.123808072164
# SE t8 é B5 E t9 é B2 E t6 é B2 E t7 é B1 E t4 é B3 E t5 é B4 E t2 é B2 E t3 é B3 E t1 é B2 ENTÃO t0 é B5 com grau 0.0605485757331
# SE t8 é B2 E t9 é B5 E t6 é B1 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B1 com grau 0.018708309208
# SE t8 é B2 E t9 é B3 E t6 é B1 E t7 é B4 E t4 é B2 E t5 é B5 E t2 é B1 E t3 é B5 E t1 é B5 ENTÃO t0 é B1 com grau 0.130156866913
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B2 E t5 é B5 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.141753704676
# SE t8 é B5 E t9 é B10 E t6 é B4 E t7 é B1 E t4 é B3 E t5 é B2 E t2 é B2 E t3 é B3 E t1 é B3 ENTÃO t0 é B2 com grau 0.0774430480005
# SE t8 é B5 E t9 é B1 E t6 é B3 E t7 é B2 E t4 é B3 E t5 é B2 E t2 é B5 E t3 é B2 E t1 é B1 ENTÃO t0 é B2 com grau 0.16826057386
# SE t8 é B4 E t9 é B1 E t6 é B2 E t7 é B3 E t4 é B2 E t5 é B5 E t2 é B3 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.0601909245838
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B1 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.0504892116649
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B1 E t4 é CE E t5 é B3 E t2 é S10 E t3 é B10 E t1 é B3 ENTÃO t0 é B2 com grau 0.0442075767061
# SE t8 é B1 E t9 é B5 E t6 é B2 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B1 ENTÃO t0 é B3 com grau 0.0594016746726
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B2 E t5 é B4 E t2 é B2 E t3 é B4 E t1 é B4 ENTÃO t0 é B4 com grau 0.040822560668
# SE t8 é B2 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B1 E t5 é B3 E t2 é B1 E t3 é B6 E t1 é B4 ENTÃO t0 é B2 com grau 0.0269204970156
# SE t8 é B4 E t9 é S1 E t6 é B1 E t7 é B4 E t4 é B2 E t5 é B3 E t2 é B4 E t3 é B4 E t1 é CE ENTÃO t0 é B6 com grau 0.199109599756
# SE t8 é B1 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B10 E t5 é CE E t2 é B3 E t3 é S10 E t1 é B2 ENTÃO t0 é B4 com grau 0.0427476203025
# SE t8 é B1 E t9 é B5 E t6 é B1 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B5 E t3 é B1 E t1 é B1 ENTÃO t0 é B4 com grau 0.141411097788
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B5 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.0982547141006
# SE t8 é B5 E t9 é B5 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B5 E t2 é B5 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.0799436224043
# SE t8 é B4 E t9 é B2 E t6 é B4 E t7 é B2 E t4 é B2 E t5 é B2 E t2 é B1 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.0519574517967
# SE t8 é B6 E t9 é B1 E t6 é B4 E t7 é CE E t4 é B3 E t5 é B2 E t2 é B1 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.0702954646171
# SE t8 é B6 E t9 é CE E t6 é B4 E t7 é CE E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.134854258634
# SE t8 é B1 E t9 é B4 E t6 é S1 E t7 é B6 E t4 é CE E t5 é B6 E t2 é B1 E t3 é B6 E t1 é B5 ENTÃO t0 é S1 com grau 0.0335181982792
# SE t8 é B5 E t9 é CE E t6 é B2 E t7 é B2 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B1 E t1 é B1 ENTÃO t0 é B4 com grau 0.0755765530751
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B2 E t4 é B1 E t5 é B5 E t2 é B4 E t3 é B3 E t1 é B1 ENTÃO t0 é B5 com grau 0.0643536090271
# SE t8 é B2 E t9 é B3 E t6 é B1 E t7 é B5 E t4 é CE E t5 é B5 E t2 é B3 E t3 é B4 E t1 é B1 ENTÃO t0 é B6 com grau 0.0573541854836
# SE t8 é B2 E t9 é B4 E t6 é B1 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B2 E t1 é B3 ENTÃO t0 é B2 com grau 0.0108119370418
# SE t8 é B3 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B2 E t3 é B4 E t1 é B4 ENTÃO t0 é B1 com grau 0.104012801378
# SE t8 é CE E t9 é B3 E t6 é S10 E t7 é B10 E t4 é B2 E t5 é B3 E t2 é S1 E t3 é B4 E t1 é B4 ENTÃO t0 é S1 com grau 0.030526669953
# SE t8 é B3 E t9 é B2 E t6 é B1 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B4 E t3 é B2 E t1 é CE ENTÃO t0 é B5 com grau 0.0867901807925
# SE t8 é B1 E t9 é B3 E t6 é CE E t7 é B6 E t4 é B1 E t5 é B5 E t2 é B1 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.0803672699073
# SE t8 é B4 E t9 é B3 E t6 é B5 E t7 é B1 E t4 é B4 E t5 é B2 E t2 é B4 E t3 é B2 E t1 é B2 ENTÃO t0 é B2 com grau 0.0305675690211
# SE t8 é B6 E t9 é S1 E t6 é B4 E t7 é CE E t4 é B4 E t5 é B1 E t2 é B2 E t3 é B3 E t1 é B5 ENTÃO t0 é B2 com grau 0.113582490455
# SE t8 é CE E t9 é B5 E t6 é B3 E t7 é B4 E t4 é B6 E t5 é B1 E t2 é B5 E t3 é CE E t1 é B2 ENTÃO t0 é B2 com grau 0.0418108045793
# SE t8 é CE E t9 é B6 E t6 é B2 E t7 é B4 E t4 é B2 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0956140012914
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B5 ENTÃO t0 é B2 com grau 0.14624388941
# SE t8 é B3 E t9 é B2 E t6 é B2 E t7 é B3 E t4 é B2 E t5 é B5 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é B2 com grau 0.0160695443253
# SE t8 é B3 E t9 é B2 E t6 é B3 E t7 é B4 E t4 é B6 E t5 é B1 E t2 é B4 E t3 é B1 E t1 é B2 ENTÃO t0 é B2 com grau 0.0321865464924
# SE t8 é B2 E t9 é B3 E t6 é B4 E t7 é B4 E t4 é B6 E t5 é CE E t2 é B6 E t3 é CE E t1 é CE ENTÃO t0 é B5 com grau 0.0958663871362
# SE t8 é B4 E t9 é B1 E t6 é B2 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B5 E t3 é B2 E t1 é B2 ENTÃO t0 é B3 com grau 0.00716789173949
# SE t8 é B4 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B5 E t1 é B4 ENTÃO t0 é B3 com grau 0.111241215345
# SE t8 é B2 E t9 é B5 E t6 é B1 E t7 é B5 E t4 é B1 E t5 é B5 E t2 é B1 E t3 é B5 E t1 é B4 ENTÃO t0 é B1 com grau 0.0429828213386
# SE t8 é B2 E t9 é B5 E t6 é B2 E t7 é B3 E t4 é B2 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B2 ENTÃO t0 é B4 com grau 0.0377050963229
# SE t8 é B3 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B2 E t2 é B4 E t3 é B2 E t1 é B4 ENTÃO t0 é B2 com grau 0.0219935821473
# SE t8 é B4 E t9 é B4 E t6 é B5 E t7 é B2 E t4 é B3 E t5 é B2 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.0413594646894
# SE t8 é B3 E t9 é B3 E t6 é B5 E t7 é B2 E t4 é B3 E t5 é B2 E t2 é B4 E t3 é B2 E t1 é B2 ENTÃO t0 é B3 com grau 0.0217606608718
# SE t8 é B2 E t9 é B4 E t6 é B4 E t7 é B2 E t4 é B4 E t5 é B1 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é B2 com grau 0.0290007562781
# SE t8 é B3 E t9 é B5 E t6 é B3 E t7 é B4 E t4 é B5 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B4 com grau 0.150399628443
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B5 E t4 é B5 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B5 ENTÃO t0 é B3 com grau 0.053594438781
# SE t8 é B4 E t9 é B4 E t6 é B6 E t7 é CE E t4 é B6 E t5 é CE E t2 é B5 E t3 é CE E t1 é CE ENTÃO t0 é B4 com grau 0.0435686289513
# SE t8 é B3 E t9 é B2 E t6 é B3 E t7 é B4 E t4 é B5 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B4 com grau 0.0621726665058
# SE t8 é CE E t9 é B4 E t6 é B1 E t7 é B5 E t4 é B4 E t5 é B3 E t2 é B5 E t3 é CE E t1 é B1 ENTÃO t0 é B3 com grau 0.179198690906
# SE t8 é B3 E t9 é B2 E t6 é B1 E t7 é B5 E t4 é B4 E t5 é B3 E t2 é B5 E t3 é B1 E t1 é B2 ENTÃO t0 é B2 com grau 0.0570153611045
# SE t8 é B3 E t9 é B5 E t6 é B3 E t7 é B3 E t4 é B2 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B2 ENTÃO t0 é B4 com grau 0.0477646820635
# SE t8 é CE E t9 é B4 E t6 é B2 E t7 é B5 E t4 é B1 E t5 é B3 E t2 é CE E t3 é B6 E t1 é B4 ENTÃO t0 é B2 com grau 0.0445876210977
# SE t8 é B4 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B4 E t2 é B5 E t3 é B3 E t1 é B3 ENTÃO t0 é B4 com grau 0.0301474270329
# SE t8 é B2 E t9 é B3 E t6 é CE E t7 é B5 E t4 é B1 E t5 é B5 E t2 é B4 E t3 é B3 E t1 é CE ENTÃO t0 é B6 com grau 0.0980740893284
# SE t8 é B1 E t9 é B4 E t6 é B2 E t7 é B5 E t4 é B2 E t5 é B4 E t2 é B2 E t3 é B4 E t1 é B2 ENTÃO t0 é B4 com grau 0.0294204074498
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B2 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B5 com grau 0.0456182225779
# SE t8 é B2 E t9 é B3 E t6 é CE E t7 é B4 E t4 é B2 E t5 é B5 E t2 é B1 E t3 é B3 E t1 é B6 ENTÃO t0 é CE com grau 0.053371057044
# SE t8 é B2 E t9 é B5 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B2 E t2 é B4 E t3 é B2 E t1 é B1 ENTÃO t0 é B4 com grau 0.0519417120893
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B4 E t4 é B5 E t5 é B5 E t2 é B4 E t3 é B3 E t1 é B5 ENTÃO t0 é B4 com grau 0.107323590177
# SE t8 é B4 E t9 é B1 E t6 é B3 E t7 é B2 E t4 é B2 E t5 é B2 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.160496100769
# SE t8 é B2 E t9 é B5 E t6 é B5 E t7 é B3 E t4 é B5 E t5 é CE E t2 é B3 E t3 é B2 E t1 é B4 ENTÃO t0 é B2 com grau 0.0572456766918
# SE t8 é B2 E t9 é B4 E t6 é B1 E t7 é B4 E t4 é S1 E t5 é B6 E t2 é CE E t3 é B6 E t1 é B6 ENTÃO t0 é B1 com grau 0.0867592757572
# SE t8 é B3 E t9 é B5 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.164986601248
# SE t8 é B1 E t9 é B5 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B2 E t3 é B3 E t1 é B3 ENTÃO t0 é B5 com grau 0.108918425893
# SE t8 é B1 E t9 é B5 E t6 é B2 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B2 E t1 é B2 ENTÃO t0 é B5 com grau 0.142386898712
# SE t8 é B2 E t9 é B3 E t6 é B1 E t7 é B4 E t4 é CE E t5 é B6 E t2 é S1 E t3 é B5 E t1 é B4 ENTÃO t0 é B4 com grau 0.0565937379329
# SE t8 é B4 E t9 é CE E t6 é B3 E t7 é B2 E t4 é B1 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B2 ENTÃO t0 é B4 com grau 0.0846872746536
# SE t8 é B3 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B3 E t1 é B2 ENTÃO t0 é B3 com grau 0.0985368976945
# SE t8 é B1 E t9 é B5 E t6 é B3 E t7 é B4 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B1 E t1 é B5 ENTÃO t0 é S1 com grau 0.0733020537971
# SE t8 é B4 E t9 é B3 E t6 é B5 E t7 é B2 E t4 é B4 E t5 é B1 E t2 é B4 E t3 é B2 E t1 é B2 ENTÃO t0 é B3 com grau 0.0339625089246
# SE t8 é B5 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B5 E t2 é B4 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.0458205169376
# SE t8 é B5 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0616790321049
# SE t8 é B2 E t9 é B4 E t6 é B2 E t7 é B4 E t4 é B4 E t5 é B2 E t2 é B4 E t3 é B1 E t1 é B3 ENTÃO t0 é B2 com grau 0.0383195291856
# SE t8 é B4 E t9 é B1 E t6 é B2 E t7 é B3 E t4 é B1 E t5 é B4 E t2 é B1 E t3 é B5 E t1 é B3 ENTÃO t0 é B2 com grau 0.0386002328992
# SE t8 é B4 E t9 é B2 E t6 é B4 E t7 é B1 E t4 é B2 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B2 ENTÃO t0 é B5 com grau 0.00763827158413
# SE t8 é B4 E t9 é B3 E t6 é B5 E t7 é B1 E t4 é B2 E t5 é B2 E t2 é B2 E t3 é B4 E t1 é B4 ENTÃO t0 é B1 com grau 0.129397780288
# SE t8 é B3 E t9 é B4 E t6 é B4 E t7 é B4 E t4 é B1 E t5 é B3 E t2 é B1 E t3 é B5 E t1 é B5 ENTÃO t0 é B1 com grau 0.0752395200105
# SE t8 é B3 E t9 é B3 E t6 é B2 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B5 E t3 é B3 E t1 é B2 ENTÃO t0 é B4 com grau 0.126612532738
# SE t8 é B5 E t9 é B2 E t6 é B4 E t7 é B1 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.0503498909247
# SE t8 é B3 E t9 é B4 E t6 é B3 E t7 é B5 E t4 é B5 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B3 ENTÃO t0 é B4 com grau 0.102876653912
# SE t8 é B2 E t9 é B5 E t6 é B1 E t7 é B3 E t4 é CE E t5 é B6 E t2 é B2 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.0521573223528
# SE t8 é B2 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.0505205413392
# SE t8 é B2 E t9 é B4 E t6 é CE E t7 é B5 E t4 é CE E t5 é B6 E t2 é B2 E t3 é B4 E t1 é B4 ENTÃO t0 é B2 com grau 0.0678286142173
# SE t8 é B5 E t9 é B3 E t6 é B5 E t7 é CE E t4 é B3 E t5 é B2 E t2 é B2 E t3 é B4 E t1 é B4 ENTÃO t0 é B2 com grau 0.051977107738
# SE t8 é B2 E t9 é B3 E t6 é B3 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B4 com grau 0.0531050218134
# SE t8 é CE E t9 é B6 E t6 é B1 E t7 é B5 E t4 é B1 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B1 ENTÃO t0 é B5 com grau 0.0744474781512
# SE t8 é B3 E t9 é B5 E t6 é B4 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B5 com grau 0.0650225379559
# SE t8 é B3 E t9 é B2 E t6 é B1 E t7 é B4 E t4 é B1 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B2 ENTÃO t0 é B4 com grau 0.0551338499574
# SE t8 é B2 E t9 é B1 E t6 é B3 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B2 E t1 é B5 ENTÃO t0 é B1 com grau 0.0718117575246
# SE t8 é B5 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B2 E t1 é B3 ENTÃO t0 é B2 com grau 0.0471768790328
# SE t8 é B2 E t9 é B4 E t6 é B4 E t7 é B4 E t4 é B5 E t5 é B2 E t2 é B3 E t3 é B2 E t1 é B3 ENTÃO t0 é B2 com grau 0.03370933596
# SE t8 é B3 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.0689279376135
# SE t8 é B3 E t9 é B3 E t6 é B1 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B10 E t3 é CE E t1 é S10 ENTÃO t0 é B3 com grau 0.0318363006743
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B5 E t4 é B4 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.0410913391308
# SE t8 é B2 E t9 é B2 E t6 é B3 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B5 E t3 é B1 E t1 é B2 ENTÃO t0 é B5 com grau 0.134020499743
# SE t8 é B3 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B5 E t5 é B1 E t2 é B5 E t3 é B2 E t1 é B2 ENTÃO t0 é B3 com grau 0.14782327913
# SE t8 é B2 E t9 é B3 E t6 é CE E t7 é B4 E t4 é B1 E t5 é B5 E t2 é B4 E t3 é B3 E t1 é CE ENTÃO t0 é B5 com grau 0.343294007111
# SE t8 é B2 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B5 E t5 é B3 E t2 é B4 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.135980646223
# SE t8 é B3 E t9 é B1 E t6 é CE E t7 é B3 E t4 é S10 E t5 é B10 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é S1 com grau 0.0321644151557
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B1 E t5 é B3 E t2 é B2 E t3 é B5 E t1 é B5 ENTÃO t0 é B2 com grau 0.118601593861
# SE t8 é CE E t9 é B6 E t6 é B1 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B5 E t3 é B2 E t1 é B2 ENTÃO t0 é B2 com grau 0.116137516111
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B2 E t5 é B3 E t2 é B5 E t3 é B3 E t1 é B1 ENTÃO t0 é B3 com grau 0.0913598251169
# SE t8 é B1 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B5 E t5 é B1 E t2 é B4 E t3 é B1 E t1 é B3 ENTÃO t0 é B2 com grau 0.123135756831
# SE t8 é B4 E t9 é CE E t6 é B3 E t7 é B2 E t4 é B6 E t5 é B1 E t2 é B5 E t3 é CE E t1 é B1 ENTÃO t0 é B4 com grau 0.059071462819
# SE t8 é B1 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B3 E t5 é B2 E t2 é B2 E t3 é B3 E t1 é B5 ENTÃO t0 é B2 com grau 0.00623851665555
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B2 E t3 é B5 E t1 é B4 ENTÃO t0 é B3 com grau 0.120286713752
# SE t8 é B2 E t9 é B4 E t6 é B1 E t7 é B5 E t4 é B2 E t5 é B4 E t2 é B2 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.0341674813879
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B2 com grau 0.127306201345
# SE t8 é B4 E t9 é B2 E t6 é B4 E t7 é B2 E t4 é B6 E t5 é B1 E t2 é B6 E t3 é S1 E t1 é CE ENTÃO t0 é B6 com grau 0.083959752182
# SE t8 é B2 E t9 é B4 E t6 é B2 E t7 é B4 E t4 é B4 E t5 é B4 E t2 é B5 E t3 é B2 E t1 é B2 ENTÃO t0 é B3 com grau 0.03670852256
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B4 E t4 é B5 E t5 é B1 E t2 é B5 E t3 é B1 E t1 é B1 ENTÃO t0 é B3 com grau 0.0949998660124
# SE t8 é B3 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B5 E t1 é B4 ENTÃO t0 é B5 com grau 0.0468971786716
# SE t8 é B2 E t9 é B5 E t6 é B2 E t7 é B5 E t4 é B2 E t5 é B3 E t2 é CE E t3 é B5 E t1 é B5 ENTÃO t0 é B1 com grau 0.0931312791818
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B2 com grau 0.0476860693686
# SE t8 é B3 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B5 E t5 é B3 E t2 é B4 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.0960465265258
# SE t8 é CE E t9 é B5 E t6 é B2 E t7 é B5 E t4 é B3 E t5 é B2 E t2 é B1 E t3 é B4 E t1 é B4 ENTÃO t0 é B1 com grau 0.112061549031
# SE t8 é B2 E t9 é B3 E t6 é B1 E t7 é B5 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B2 com grau 0.133943089856
# SE t8 é B2 E t9 é B1 E t6 é B3 E t7 é B4 E t4 é B2 E t5 é B3 E t2 é B5 E t3 é B2 E t1 é CE ENTÃO t0 é B5 com grau 0.102723258161
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B2 E t1 é B4 ENTÃO t0 é B3 com grau 0.10464675941
# SE t8 é B5 E t9 é B1 E t6 é B5 E t7 é B2 E t4 é B5 E t5 é B1 E t2 é B5 E t3 é B1 E t1 é B1 ENTÃO t0 é B4 com grau 0.0532038814815
# SE t8 é B5 E t9 é B3 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B5 E t2 é B3 E t3 é B4 E t1 é B4 ENTÃO t0 é B5 com grau 0.101582011787
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B2 E t4 é B2 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.0616361189461
# SE t8 é B5 E t9 é B2 E t6 é B5 E t7 é B1 E t4 é B4 E t5 é B2 E t2 é B4 E t3 é B1 E t1 é B3 ENTÃO t0 é B3 com grau 0.0419867599839
# SE t8 é B5 E t9 é B2 E t6 é B6 E t7 é CE E t4 é B4 E t5 é CE E t2 é B4 E t3 é B2 E t1 é B2 ENTÃO t0 é B3 com grau 0.0950473937683
# SE t8 é B2 E t9 é B5 E t6 é B3 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B2 E t1 é B1 ENTÃO t0 é B5 com grau 0.0774706113249
# SE t8 é B2 E t9 é B4 E t6 é B2 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.0608032171925
# SE t8 é B3 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B1 E t5 é B4 E t2 é B2 E t3 é B5 E t1 é B4 ENTÃO t0 é B2 com grau 0.0304623890315
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B2 com grau 0.154230566886
# SE t8 é B2 E t9 é B4 E t6 é B2 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B4 com grau 0.130655812482
# SE t8 é B3 E t9 é B1 E t6 é B1 E t7 é B4 E t4 é B2 E t5 é B5 E t2 é B4 E t3 é B2 E t1 é B2 ENTÃO t0 é B4 com grau 0.12588198525
# SE t8 é B3 E t9 é B3 E t6 é B5 E t7 é B1 E t4 é B5 E t5 é B2 E t2 é B3 E t3 é B2 E t1 é B2 ENTÃO t0 é B5 com grau 0.162016159572
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B2 E t2 é B3 E t3 é B4 E t1 é B2 ENTÃO t0 é B5 com grau 0.0872992095958
# SE t8 é B2 E t9 é B2 E t6 é B1 E t7 é B5 E t4 é B2 E t5 é B5 E t2 é B1 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.0331164902596
# SE t8 é B2 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0794986585078
# SE t8 é B4 E t9 é B1 E t6 é B2 E t7 é B3 E t4 é B1 E t5 é B4 E t2 é B5 E t3 é B3 E t1 é S1 ENTÃO t0 é B10 com grau 0.0672140697108
# SE t8 é B3 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B2 com grau 0.0497896780152
# SE t8 é B1 E t9 é B3 E t6 é B3 E t7 é B4 E t4 é B4 E t5 é B2 E t2 é B5 E t3 é CE E t1 é B1 ENTÃO t0 é B5 com grau 0.072174126397
# SE t8 é B4 E t9 é B1 E t6 é B4 E t7 é B1 E t4 é B5 E t5 é B2 E t2 é B2 E t3 é B1 E t1 é B4 ENTÃO t0 é B3 com grau 0.0405107304261
# SE t8 é B4 E t9 é B3 E t6 é B5 E t7 é CE E t4 é B3 E t5 é B1 E t2 é B1 E t3 é B4 E t1 é B4 ENTÃO t0 é B2 com grau 0.126277632828
# SE t8 é B3 E t9 é B5 E t6 é B5 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.0368761416402
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B2 E t4 é B5 E t5 é B2 E t2 é B5 E t3 é B1 E t1 é CE ENTÃO t0 é B4 com grau 0.0571335545073
# SE t8 é B4 E t9 é B2 E t6 é CE E t7 é B4 E t4 é CE E t5 é B6 E t2 é CE E t3 é B6 E t1 é B5 ENTÃO t0 é CE com grau 0.0601337835596
# SE t8 é B3 E t9 é B4 E t6 é B4 E t7 é B2 E t4 é B5 E t5 é CE E t2 é B5 E t3 é B1 E t1 é B2 ENTÃO t0 é B3 com grau 0.136711957168
# SE t8 é B4 E t9 é B1 E t6 é B2 E t7 é B3 E t4 é CE E t5 é B4 E t2 é B1 E t3 é B5 E t1 é B5 ENTÃO t0 é B2 com grau 0.0909913827835
# SE t8 é B1 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B4 E t5 é B2 E t2 é B5 E t3 é B1 E t1 é B1 ENTÃO t0 é B3 com grau 0.033581214089
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.0631694035052
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B2 E t4 é B3 E t5 é B4 E t2 é B5 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0325326798233
# SE t8 é B4 E t9 é B1 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B4 com grau 0.037708670151
# SE t8 é B4 E t9 é B4 E t6 é B3 E t7 é B1 E t4 é B4 E t5 é B2 E t2 é CE E t3 é B4 E t1 é B6 ENTÃO t0 é CE com grau 0.19448358253
# SE t8 é B3 E t9 é B4 E t6 é B4 E t7 é B4 E t4 é B5 E t5 é B3 E t2 é B3 E t3 é B5 E t1 é B4 ENTÃO t0 é B5 com grau 0.0814164369283
# SE t8 é B2 E t9 é B3 E t6 é B2 E t7 é B3 E t4 é B1 E t5 é B5 E t2 é B4 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.160204500024
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B4 E t4 é B5 E t5 é B3 E t2 é B4 E t3 é B3 E t1 é B5 ENTÃO t0 é B3 com grau 0.0693728433692
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B2 E t2 é B5 E t3 é B1 E t1 é B2 ENTÃO t0 é B3 com grau 0.0929102593018
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B2 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.0774540894002
# SE t8 é S1 E t9 é B5 E t6 é B5 E t7 é B10 E t4 é B4 E t5 é B1 E t2 é B3 E t3 é B2 E t1 é B3 ENTÃO t0 é B2 com grau 0.105081970533
# SE t8 é B3 E t9 é B4 E t6 é B6 E t7 é B1 E t4 é B4 E t5 é B1 E t2 é B2 E t3 é B2 E t1 é B3 ENTÃO t0 é B2 com grau 0.0239956135525
# SE t8 é B4 E t9 é B1 E t6 é B2 E t7 é B2 E t4 é B2 E t5 é B3 E t2 é B1 E t3 é B4 E t1 é B6 ENTÃO t0 é CE com grau 0.0453198323606
# SE t8 é B2 E t9 é B4 E t6 é B1 E t7 é B4 E t4 é B2 E t5 é B5 E t2 é B5 E t3 é B3 E t1 é CE ENTÃO t0 é B5 com grau 0.034583399379
# SE t8 é B3 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B3 E t2 é B5 E t3 é B2 E t1 é B1 ENTÃO t0 é B4 com grau 0.0637639169419
# SE t8 é B3 E t9 é B4 E t6 é B2 E t7 é B3 E t4 é B5 E t5 é B2 E t2 é B5 E t3 é CE E t1 é B2 ENTÃO t0 é B2 com grau 0.188101357025
# SE t8 é B3 E t9 é B3 E t6 é B2 E t7 é B3 E t4 é B5 E t5 é B3 E t2 é B3 E t3 é B1 E t1 é B4 ENTÃO t0 é B1 com grau 0.0559526640483
# SE t8 é B1 E t9 é B4 E t6 é B2 E t7 é B5 E t4 é B5 E t5 é B3 E t2 é B5 E t3 é CE E t1 é B2 ENTÃO t0 é B3 com grau 0.0629857067449
# SE t8 é B2 E t9 é B5 E t6 é B5 E t7 é B2 E t4 é B5 E t5 é B1 E t2 é B4 E t3 é B2 E t1 é B1 ENTÃO t0 é B4 com grau 0.024244658591
# SE t8 é B3 E t9 é B2 E t6 é B4 E t7 é B2 E t4 é B6 E t5 é B1 E t2 é B5 E t3 é CE E t1 é S1 ENTÃO t0 é B4 com grau 0.0421480953782
# SE t8 é B4 E t9 é B1 E t6 é B5 E t7 é B2 E t4 é B2 E t5 é B1 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B2 com grau 0.0676618898216
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B1 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0352798635055
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B5 E t2 é B4 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.052602866637
# SE t8 é CE E t9 é B6 E t6 é B2 E t7 é B5 E t4 é B5 E t5 é B2 E t2 é B5 E t3 é B1 E t1 é B2 ENTÃO t0 é B4 com grau 0.025884060738
# SE t8 é B1 E t9 é B3 E t6 é CE E t7 é B6 E t4 é B2 E t5 é B5 E t2 é B5 E t3 é B2 E t1 é B1 ENTÃO t0 é B5 com grau 0.0621454540868
# SE t8 é B5 E t9 é CE E t6 é B3 E t7 é B2 E t4 é B2 E t5 é B4 E t2 é B2 E t3 é B4 E t1 é B4 ENTÃO t0 é B1 com grau 0.0533590797774
# SE t8 é B2 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B3 E t1 é B2 ENTÃO t0 é B5 com grau 0.0445172536287
# SE t8 é B6 E t9 é CE E t6 é B6 E t7 é S1 E t4 é B4 E t5 é CE E t2 é B4 E t3 é B1 E t1 é B3 ENTÃO t0 é B2 com grau 0.175200538492
# SE t8 é B5 E t9 é CE E t6 é B4 E t7 é B1 E t4 é B3 E t5 é B2 E t2 é B2 E t3 é B2 E t1 é B4 ENTÃO t0 é B3 com grau 0.130974243899
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B1 E t4 é B4 E t5 é B1 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é B1 com grau 0.0450686630136
# SE t8 é S1 E t9 é B4 E t6 é B2 E t7 é B5 E t4 é B1 E t5 é B4 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é CE com grau 0.102650683795
# SE t8 é B3 E t9 é B2 E t6 é B5 E t7 é B2 E t4 é B5 E t5 é CE E t2 é B3 E t3 é B1 E t1 é B4 ENTÃO t0 é CE com grau 0.107742343866
# SE t8 é B5 E t9 é B2 E t6 é B5 E t7 é B1 E t4 é B5 E t5 é B1 E t2 é B4 E t3 é B1 E t1 é B1 ENTÃO t0 é B4 com grau 0.0329286548736
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B2 E t3 é B4 E t1 é B5 ENTÃO t0 é B1 com grau 0.0585799893391
# SE t8 é CE E t9 é B6 E t6 é B1 E t7 é B5 E t4 é B2 E t5 é B4 E t2 é B2 E t3 é B3 E t1 é B2 ENTÃO t0 é B4 com grau 0.15490780129
# SE t8 é B1 E t9 é B5 E t6 é B2 E t7 é B4 E t4 é B2 E t5 é B3 E t2 é B4 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.103275764049
# SE t8 é B5 E t9 é B2 E t6 é B5 E t7 é B1 E t4 é B4 E t5 é CE E t2 é B1 E t3 é B3 E t1 é B6 ENTÃO t0 é CE com grau 0.0556196867882
# SE t8 é B3 E t9 é B3 E t6 é B2 E t7 é B2 E t4 é CE E t5 é B5 E t2 é B2 E t3 é B5 E t1 é B2 ENTÃO t0 é B3 com grau 0.133809053963
# SE t8 é B5 E t9 é B2 E t6 é B3 E t7 é B2 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B2 E t1 é B4 ENTÃO t0 é B2 com grau 0.0273670487594
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B2 E t5 é B4 E t2 é B1 E t3 é B4 E t1 é B5 ENTÃO t0 é B2 com grau 0.0871234811878
# SE t8 é B3 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B2 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0578361324572
# SE t8 é B3 E t9 é B4 E t6 é B5 E t7 é B3 E t4 é B4 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.0884833368292
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B4 E t4 é B4 E t5 é B4 E t2 é B5 E t3 é B3 E t1 é B5 ENTÃO t0 é B3 com grau 0.0795980365072
# SE t8 é S1 E t9 é B6 E t6 é CE E t7 é B6 E t4 é B1 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B2 ENTÃO t0 é B5 com grau 0.174269712765
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B2 com grau 0.127915912043
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B2 E t4 é B4 E t5 é B2 E t2 é B2 E t3 é B4 E t1 é B5 ENTÃO t0 é B2 com grau 0.0242684385256
# SE t8 é B2 E t9 é B3 E t6 é B2 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.0579466398091
# SE t8 é B3 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.0714835670605
# SE t8 é B3 E t9 é B2 E t6 é B2 E t7 é B2 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B1 ENTÃO t0 é B5 com grau 0.192976632826
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B3 E t1 é B2 ENTÃO t0 é B4 com grau 0.134824810262
# SE t8 é B3 E t9 é B1 E t6 é CE E t7 é B4 E t4 é B1 E t5 é B5 E t2 é B4 E t3 é B3 E t1 é B1 ENTÃO t0 é B4 com grau 0.210521971472
# SE t8 é B5 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.113164451927
# SE t8 é B3 E t9 é B2 E t6 é B3 E t7 é B2 E t4 é B5 E t5 é B2 E t2 é B2 E t3 é B1 E t1 é B4 ENTÃO t0 é B3 com grau 0.156835672068
# SE t8 é B6 E t9 é B1 E t6 é B5 E t7 é CE E t4 é B4 E t5 é B1 E t2 é B4 E t3 é B1 E t1 é B3 ENTÃO t0 é B1 com grau 0.126645221174
# SE t8 é B3 E t9 é B3 E t6 é B1 E t7 é B3 E t4 é B2 E t5 é B5 E t2 é B2 E t3 é B5 E t1 é B3 ENTÃO t0 é B2 com grau 0.125744208156
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B5 E t4 é B3 E t5 é B4 E t2 é B4 E t3 é B4 E t1 é B3 ENTÃO t0 é B1 com grau 0.117457258948
# SE t8 é B1 E t9 é B4 E t6 é B2 E t7 é B3 E t4 é B4 E t5 é B4 E t2 é B6 E t3 é CE E t1 é CE ENTÃO t0 é B6 com grau 0.149865749408
# SE t8 é B2 E t9 é B3 E t6 é B3 E t7 é B5 E t4 é B3 E t5 é B3 E t2 é B2 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.0501171915686
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B2 E t4 é B5 E t5 é B1 E t2 é B3 E t3 é B2 E t1 é B5 ENTÃO t0 é CE com grau 0.0622448996237
# SE t8 é B2 E t9 é B3 E t6 é B1 E t7 é B4 E t4 é B1 E t5 é B5 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.0444209279084
# SE t8 é B3 E t9 é B5 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B4 E t3 é B4 E t1 é B3 ENTÃO t0 é B5 com grau 0.0820074247168
# SE t8 é B2 E t9 é B3 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B1 E t3 é B3 E t1 é B5 ENTÃO t0 é B2 com grau 0.138313308953
# SE t8 é B5 E t9 é B2 E t6 é B5 E t7 é CE E t4 é B2 E t5 é B2 E t2 é B4 E t3 é B3 E t1 é B1 ENTÃO t0 é B4 com grau 0.0989225025508
# SE t8 é S10 E t9 é B10 E t6 é B2 E t7 é B3 E t4 é S1 E t5 é B4 E t2 é S1 E t3 é B4 E t1 é B5 ENTÃO t0 é B2 com grau 0.0287891396989
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B2 E t4 é B3 E t5 é B4 E t2 é B5 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.0358827021585
# SE t8 é B3 E t9 é B4 E t6 é B5 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.140763419922
# SE t8 é B3 E t9 é B4 E t6 é B6 E t7 é B1 E t4 é B5 E t5 é CE E t2 é B2 E t3 é B2 E t1 é B5 ENTÃO t0 é B1 com grau 0.0469282298972
# SE t8 é B2 E t9 é B5 E t6 é B3 E t7 é B2 E t4 é B1 E t5 é B4 E t2 é B1 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.0607053469443
# SE t8 é B3 E t9 é B2 E t6 é B2 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B4 com grau 0.0818606309671
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B1 com grau 0.05760378741
# SE t8 é B3 E t9 é B3 E t6 é B2 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B4 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.0833057319148
# SE t8 é B1 E t9 é B5 E t6 é B4 E t7 é B3 E t4 é B5 E t5 é B1 E t2 é B2 E t3 é B2 E t1 é B4 ENTÃO t0 é B2 com grau 0.0742262811376
# SE t8 é B1 E t9 é B3 E t6 é B1 E t7 é B5 E t4 é B3 E t5 é B4 E t2 é B4 E t3 é B2 E t1 é B1 ENTÃO t0 é B3 com grau 0.0928139466348
# SE t8 é B2 E t9 é B3 E t6 é B2 E t7 é B4 E t4 é CE E t5 é B5 E t2 é CE E t3 é B6 E t1 é B4 ENTÃO t0 é B2 com grau 0.039135606081
# SE t8 é B6 E t9 é B1 E t6 é B5 E t7 é CE E t4 é B4 E t5 é S1 E t2 é B1 E t3 é B4 E t1 é B3 ENTÃO t0 é B2 com grau 0.102500532849
# SE t8 é B4 E t9 é B2 E t6 é B2 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0446472199571
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B1 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0386153889098
# SE t8 é B2 E t9 é B5 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B2 ENTÃO t0 é B4 com grau 0.13560195391
# SE t8 é B4 E t9 é B2 E t6 é B4 E t7 é B2 E t4 é B2 E t5 é B4 E t2 é B2 E t3 é B5 E t1 é B3 ENTÃO t0 é B3 com grau 0.0415491747024
# SE t8 é B5 E t9 é CE E t6 é B3 E t7 é B2 E t4 é B6 E t5 é B1 E t2 é B4 E t3 é CE E t1 é B2 ENTÃO t0 é B3 com grau 0.0480853855283
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B4 com grau 0.0120598248241
# SE t8 é B1 E t9 é B4 E t6 é B1 E t7 é B5 E t4 é B2 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.0407989035921
# SE t8 é B3 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B1 E t2 é CE E t3 é B3 E t1 é B10 ENTÃO t0 é S10 com grau 0.0356942116949
# SE t8 é B4 E t9 é B2 E t6 é B5 E t7 é CE E t4 é B5 E t5 é B1 E t2 é B3 E t3 é B2 E t1 é B2 ENTÃO t0 é B3 com grau 0.152958915507
# SE t8 é B3 E t9 é B4 E t6 é B5 E t7 é B2 E t4 é B2 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B2 com grau 0.0750629993029
# SE t8 é B1 E t9 é B5 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B1 E t2 é B3 E t3 é B2 E t1 é B4 ENTÃO t0 é B3 com grau 0.0592807770072
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B2 E t1 é B4 ENTÃO t0 é B3 com grau 0.063900045516
# SE t8 é B5 E t9 é B3 E t6 é B4 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B1 ENTÃO t0 é B5 com grau 0.120874760579
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B1 E t4 é S1 E t5 é B5 E t2 é B5 E t3 é B10 E t1 é B1 ENTÃO t0 é B4 com grau 0.0348614933201
# SE t8 é B2 E t9 é B2 E t6 é B2 E t7 é B3 E t4 é B1 E t5 é B4 E t2 é CE E t3 é B6 E t1 é B5 ENTÃO t0 é S1 com grau 0.0262166590712
# SE t8 é B4 E t9 é B1 E t6 é B4 E t7 é B1 E t4 é B1 E t5 é B3 E t2 é B1 E t3 é B5 E t1 é B4 ENTÃO t0 é B3 com grau 0.11830487831
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B4 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.0692046798423
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.0216090484706
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B2 E t3 é B4 E t1 é B4 ENTÃO t0 é B2 com grau 0.0451279232087
# SE t8 é B3 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0632340727613
# SE t8 é B1 E t9 é B5 E t6 é B1 E t7 é B5 E t4 é B1 E t5 é B5 E t2 é B1 E t3 é B4 E t1 é B4 ENTÃO t0 é B2 com grau 0.0515476419122
# SE t8 é B4 E t9 é CE E t6 é B4 E t7 é B1 E t4 é B2 E t5 é B3 E t2 é B2 E t3 é B5 E t1 é B2 ENTÃO t0 é B3 com grau 0.12874822767
# SE t8 é B2 E t9 é B3 E t6 é B1 E t7 é B4 E t4 é B5 E t5 é B3 E t2 é B10 E t3 é S1 E t1 é B5 ENTÃO t0 é B1 com grau 0.0489295232134
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B2 E t4 é B2 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.0704830638081
# SE t8 é B3 E t9 é B1 E t6 é S1 E t7 é B5 E t4 é B5 E t5 é B10 E t2 é B4 E t3 é B1 E t1 é B2 ENTÃO t0 é B3 com grau 0.0337445280759
# SE t8 é B4 E t9 é B3 E t6 é B1 E t7 é B3 E t4 é B1 E t5 é B6 E t2 é B2 E t3 é B4 E t1 é B2 ENTÃO t0 é B3 com grau 0.0281543655344
# SE t8 é B2 E t9 é B2 E t6 é B2 E t7 é B4 E t4 é B1 E t5 é B4 E t2 é S1 E t3 é B6 E t1 é B6 ENTÃO t0 é CE com grau 0.072016125597
# SE t8 é B4 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B5 ENTÃO t0 é B3 com grau 0.017773032882
# SE t8 é B5 E t9 é B1 E t6 é B4 E t7 é B2 E t4 é B4 E t5 é B2 E t2 é B2 E t3 é B2 E t1 é B4 ENTÃO t0 é B1 com grau 0.0393608837147
# SE t8 é B2 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B5 E t1 é B3 ENTÃO t0 é B4 com grau 0.0262562987045
# SE t8 é CE E t9 é B5 E t6 é B1 E t7 é B5 E t4 é B4 E t5 é B3 E t2 é B6 E t3 é CE E t1 é S1 ENTÃO t0 é B6 com grau 0.0889388302714
# SE t8 é B4 E t9 é B1 E t6 é B3 E t7 é B2 E t4 é B3 E t5 é B4 E t2 é B6 E t3 é B1 E t1 é B1 ENTÃO t0 é B4 com grau 0.029000636817
# SE t8 é B3 E t9 é B4 E t6 é B4 E t7 é B2 E t4 é B5 E t5 é B2 E t2 é B6 E t3 é CE E t1 é CE ENTÃO t0 é B4 com grau 0.0573342411195
# SE t8 é B3 E t9 é B4 E t6 é B5 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.096839445523
# SE t8 é B5 E t9 é CE E t6 é B5 E t7 é B1 E t4 é B3 E t5 é B2 E t2 é B3 E t3 é B2 E t1 é B2 ENTÃO t0 é B5 com grau 0.151420818079
# SE t8 é CE E t9 é B6 E t6 é CE E t7 é B5 E t4 é B2 E t5 é B4 E t2 é B1 E t3 é B3 E t1 é B6 ENTÃO t0 é CE com grau 0.0399762260039
# SE t8 é B5 E t9 é B3 E t6 é B10 E t7 é S1 E t4 é B1 E t5 é B5 E t2 é B2 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.0536550830112
# SE t8 é B5 E t9 é CE E t6 é B3 E t7 é B1 E t4 é CE E t5 é B4 E t2 é B1 E t3 é B5 E t1 é B3 ENTÃO t0 é B4 com grau 0.175260541694
# SE t8 é B3 E t9 é B2 E t6 é B6 E t7 é B1 E t4 é B5 E t5 é CE E t2 é B4 E t3 é B1 E t1 é B1 ENTÃO t0 é B4 com grau 0.0625455848232
# SE t8 é B2 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B1 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é CE com grau 0.0671208752772
# SE t8 é S1 E t9 é B4 E t6 é S1 E t7 é B4 E t4 é B2 E t5 é B5 E t2 é B1 E t3 é B4 E t1 é B3 ENTÃO t0 é B2 com grau 0.0493749032414
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B3 ENTÃO t0 é B4 com grau 0.218197147193
# SE t8 é B3 E t9 é B4 E t6 é B5 E t7 é B1 E t4 é B4 E t5 é B1 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é B1 com grau 0.156207222042
# SE t8 é B4 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B4 ENTÃO t0 é B4 com grau 0.149615853597
# SE t8 é B3 E t9 é B2 E t6 é B5 E t7 é B2 E t4 é B5 E t5 é B1 E t2 é B4 E t3 é CE E t1 é B3 ENTÃO t0 é B1 com grau 0.03563414365
# SE t8 é B5 E t9 é B2 E t6 é B2 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é B1 com grau 0.0810480181
# SE t8 é B4 E t9 é B2 E t6 é B6 E t7 é B1 E t4 é B6 E t5 é S1 E t2 é B6 E t3 é CE E t1 é B1 ENTÃO t0 é B5 com grau 0.0627580282318
# SE t8 é B2 E t9 é B5 E t6 é B1 E t7 é B4 E t4 é B2 E t5 é B3 E t2 é CE E t3 é B4 E t1 é B5 ENTÃO t0 é B1 com grau 0.195520721255
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0974851325861
# SE t8 é B6 E t9 é B1 E t6 é B5 E t7 é CE E t4 é B2 E t5 é B2 E t2 é B1 E t3 é B5 E t1 é B5 ENTÃO t0 é B2 com grau 0.043086270235
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B2 E t4 é B4 E t5 é B2 E t2 é B4 E t3 é B1 E t1 é B3 ENTÃO t0 é B2 com grau 0.0229434173676
# SE t8 é B1 E t9 é B3 E t6 é B2 E t7 é B5 E t4 é B2 E t5 é B5 E t2 é B2 E t3 é B3 E t1 é B5 ENTÃO t0 é CE com grau 0.112805600208
# SE t8 é B4 E t9 é B1 E t6 é B2 E t7 é B3 E t4 é B2 E t5 é B4 E t2 é CE E t3 é B5 E t1 é B6 ENTÃO t0 é CE com grau 0.0538076667674
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B1 E t4 é B4 E t5 é B2 E t2 é B5 E t3 é CE E t1 é B1 ENTÃO t0 é B3 com grau 0.289130530308
# SE t8 é B4 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B5 E t3 é B3 E t1 é B4 ENTÃO t0 é B4 com grau 0.140481700923
# SE t8 é B5 E t9 é B2 E t6 é B3 E t7 é B2 E t4 é B5 E t5 é B2 E t2 é B5 E t3 é CE E t1 é B1 ENTÃO t0 é B3 com grau 0.121473361422
# SE t8 é B3 E t9 é B3 E t6 é B2 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0581403936867
# SE t8 é B4 E t9 é CE E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.106369734315
# SE t8 é B1 E t9 é B4 E t6 é B2 E t7 é B5 E t4 é B1 E t5 é B5 E t2 é B1 E t3 é B5 E t1 é B5 ENTÃO t0 é B1 com grau 0.0760107708369
# SE t8 é B5 E t9 é B2 E t6 é B2 E t7 é B1 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B2 ENTÃO t0 é B3 com grau 0.0984021489507
# SE t8 é B2 E t9 é B3 E t6 é B2 E t7 é B3 E t4 é B1 E t5 é B5 E t2 é CE E t3 é B5 E t1 é B4 ENTÃO t0 é B3 com grau 0.0419231948142
# SE t8 é B5 E t9 é CE E t6 é B4 E t7 é B1 E t4 é B4 E t5 é B1 E t2 é B1 E t3 é B3 E t1 é B5 ENTÃO t0 é B1 com grau 0.0858581325604
# SE t8 é B1 E t9 é B4 E t6 é B1 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B4 E t3 é B2 E t1 é B1 ENTÃO t0 é B5 com grau 0.0448800461737
# SE t8 é B5 E t9 é CE E t6 é B4 E t7 é CE E t4 é B3 E t5 é B2 E t2 é B6 E t3 é B1 E t1 é CE ENTÃO t0 é B5 com grau 0.0414743856935
# SE t8 é B3 E t9 é B4 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B1 E t2 é S1 E t3 é B5 E t1 é B10 ENTÃO t0 é B5 com grau 0.0341155710372
# SE t8 é B2 E t9 é B4 E t6 é B3 E t7 é B2 E t4 é B4 E t5 é B2 E t2 é B6 E t3 é B1 E t1 é CE ENTÃO t0 é B5 com grau 0.0409164752674
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B5 ENTÃO t0 é B5 com grau 0.0825178152137
# SE t8 é B1 E t9 é B4 E t6 é B2 E t7 é B5 E t4 é B4 E t5 é B2 E t2 é B4 E t3 é B2 E t1 é B1 ENTÃO t0 é B6 com grau 0.148241295332
# SE t8 é B1 E t9 é B5 E t6 é CE E t7 é B5 E t4 é B3 E t5 é B4 E t2 é B6 E t3 é B1 E t1 é CE ENTÃO t0 é B5 com grau 0.0436831988836
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B2 E t5 é B2 E t2 é CE E t3 é B5 E t1 é B5 ENTÃO t0 é B2 com grau 0.136263511614
# SE t8 é B6 E t9 é CE E t6 é B5 E t7 é CE E t4 é B4 E t5 é CE E t2 é B3 E t3 é B2 E t1 é B1 ENTÃO t0 é B6 com grau 0.0300926224017
# SE t8 é B1 E t9 é B4 E t6 é B2 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B1 E t3 é B3 E t1 é B6 ENTÃO t0 é B1 com grau 0.0303531394134
# SE t8 é B4 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.0459843498969
# SE t8 é B1 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B4 com grau 0.0591950836424
# SE t8 é B5 E t9 é CE E t6 é B3 E t7 é B1 E t4 é B1 E t5 é B4 E t2 é B2 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.0694370119963
# SE t8 é B2 E t9 é B2 E t6 é B4 E t7 é B3 E t4 é B4 E t5 é B1 E t2 é B4 E t3 é B1 E t1 é B3 ENTÃO t0 é B2 com grau 0.0850064199632
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.184148015333
# SE t8 é B2 E t9 é B4 E t6 é B1 E t7 é B5 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B2 ENTÃO t0 é B2 com grau 0.0792264269226
# SE t8 é B4 E t9 é B2 E t6 é B6 E t7 é B1 E t4 é B5 E t5 é CE E t2 é B4 E t3 é S1 E t1 é B4 ENTÃO t0 é B1 com grau 0.0685225740904
# SE t8 é B2 E t9 é B3 E t6 é B3 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B1 E t1 é B3 ENTÃO t0 é CE com grau 0.03490599866
# SE t8 é B1 E t9 é B5 E t6 é B4 E t7 é B3 E t4 é B6 E t5 é CE E t2 é B6 E t3 é S1 E t1 é CE ENTÃO t0 é B4 com grau 0.0907221293928
# SE t8 é B3 E t9 é B2 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B2 E t2 é B2 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.067587192687
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é B3 com grau 0.054470063604
# SE t8 é B3 E t9 é B4 E t6 é B5 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B3 E t1 é B2 ENTÃO t0 é B4 com grau 0.0580240367243
# SE t8 é B4 E t9 é B5 E t6 é B5 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B5 E t1 é B4 ENTÃO t0 é B4 com grau 0.0328953385629
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B2 ENTÃO t0 é B4 com grau 0.0666416339893
# SE t8 é B1 E t9 é B5 E t6 é B2 E t7 é B4 E t4 é B2 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0645596123431
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B2 E t4 é B5 E t5 é B1 E t2 é B5 E t3 é B2 E t1 é B1 ENTÃO t0 é B5 com grau 0.141921762399
# SE t8 é B2 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B2 E t5 é B3 E t2 é B3 E t3 é B5 E t1 é B3 ENTÃO t0 é B3 com grau 0.0463168440568
# SE t8 é B3 E t9 é B1 E t6 é B1 E t7 é B4 E t4 é B2 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B3 ENTÃO t0 é B1 com grau 0.0661302696525
# SE t8 é S1 E t9 é B5 E t6 é B4 E t7 é B4 E t4 é B3 E t5 é B1 E t2 é B4 E t3 é B2 E t1 é B4 ENTÃO t0 é CE com grau 0.158827086585
# SE t8 é B3 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.203483869012
# SE t8 é B6 E t9 é B1 E t6 é B4 E t7 é B1 E t4 é B2 E t5 é B2 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é B1 com grau 0.0350933148498
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B4 E t4 é B3 E t5 é B5 E t2 é B5 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.0852441726446
# SE t8 é B2 E t9 é B3 E t6 é B2 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B2 E t3 é B3 E t1 é B5 ENTÃO t0 é B3 com grau 0.0595981825593
# SE t8 é B3 E t9 é B3 E t6 é B4 E t7 é B3 E t4 é B5 E t5 é B2 E t2 é B4 E t3 é B1 E t1 é B2 ENTÃO t0 é B4 com grau 0.0716315467565
# SE t8 é B3 E t9 é B1 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B1 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.0377908720021
# SE t8 é B4 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B2 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.124870873033
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B5 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B4 ENTÃO t0 é B4 com grau 0.0974522194673
# SE t8 é B2 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B2 E t2 é B5 E t3 é B2 E t1 é B1 ENTÃO t0 é B5 com grau 0.0922458884857
# SE t8 é B1 E t9 é B5 E t6 é B4 E t7 é B3 E t4 é B5 E t5 é CE E t2 é B3 E t3 é B1 E t1 é B4 ENTÃO t0 é B1 com grau 0.207429563588
# SE t8 é B3 E t9 é B3 E t6 é B1 E t7 é B4 E t4 é B2 E t5 é B5 E t2 é B2 E t3 é B4 E t1 é B4 ENTÃO t0 é B2 com grau 0.0259161262559
# SE t8 é B3 E t9 é B2 E t6 é B3 E t7 é B4 E t4 é B5 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B4 com grau 0.0370103297502
# SE t8 é B1 E t9 é B6 E t6 é S1 E t7 é B5 E t4 é CE E t5 é B6 E t2 é B1 E t3 é B5 E t1 é B4 ENTÃO t0 é B2 com grau 0.0553922439292
# SE t8 é B6 E t9 é B1 E t6 é B6 E t7 é S1 E t4 é B6 E t5 é CE E t2 é B5 E t3 é B1 E t1 é S1 ENTÃO t0 é B6 com grau 0.0298162789571
# SE t8 é CE E t9 é B6 E t6 é B2 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B1 E t1 é B3 ENTÃO t0 é B2 com grau 0.0842620016155
# SE t8 é B3 E t9 é B2 E t6 é CE E t7 é B5 E t4 é B2 E t5 é B5 E t2 é B4 E t3 é B3 E t1 é B2 ENTÃO t0 é B4 com grau 0.0584344334673
# SE t8 é B5 E t9 é S1 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B1 E t2 é B4 E t3 é B2 E t1 é CE ENTÃO t0 é B5 com grau 0.160882656573
# SE t8 é B6 E t9 é S1 E t6 é B6 E t7 é CE E t4 é B5 E t5 é B1 E t2 é B6 E t3 é S1 E t1 é CE ENTÃO t0 é B5 com grau 0.0766219219962
# SE t8 é B4 E t9 é B2 E t6 é B2 E t7 é B2 E t4 é B1 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B2 ENTÃO t0 é B4 com grau 0.0318283500165
# SE t8 é B4 E t9 é S1 E t6 é B5 E t7 é S1 E t4 é B4 E t5 é B2 E t2 é B3 E t3 é B1 E t1 é B2 ENTÃO t0 é B4 com grau 0.0875799657669
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.013969403713
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B2 E t1 é B1 ENTÃO t0 é B5 com grau 0.131086905736
# SE t8 é B5 E t9 é B1 E t6 é B5 E t7 é B1 E t4 é B4 E t5 é B1 E t2 é B4 E t3 é B1 E t1 é B2 ENTÃO t0 é B5 com grau 0.0329018885535
# SE t8 é B2 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B2 E t5 é B3 E t2 é B1 E t3 é B4 E t1 é B5 ENTÃO t0 é B2 com grau 0.106334062115
# SE t8 é B3 E t9 é B3 E t6 é B2 E t7 é B4 E t4 é B1 E t5 é B5 E t2 é B2 E t3 é B4 E t1 é B4 ENTÃO t0 é B2 com grau 0.0458744131438
# SE t8 é B5 E t9 é B1 E t6 é B4 E t7 é CE E t4 é B1 E t5 é B3 E t2 é CE E t3 é B6 E t1 é B5 ENTÃO t0 é B2 com grau 0.0457522480005
# SE t8 é B4 E t9 é B4 E t6 é B4 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B5 E t3 é B5 E t1 é B3 ENTÃO t0 é B4 com grau 0.0791711204769
# SE t8 é B4 E t9 é B2 E t6 é B5 E t7 é CE E t4 é B3 E t5 é B1 E t2 é CE E t3 é B4 E t1 é B5 ENTÃO t0 é B1 com grau 0.191964122168
# SE t8 é B4 E t9 é B2 E t6 é B4 E t7 é B1 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B3 E t1 é B1 ENTÃO t0 é B5 com grau 0.0221696352698
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B4 E t4 é B3 E t5 é B3 E t2 é B2 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.0651488500047
# SE t8 é CE E t9 é B4 E t6 é S1 E t7 é B6 E t4 é CE E t5 é B6 E t2 é B1 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.139213625857
# SE t8 é B5 E t9 é CE E t6 é B4 E t7 é S1 E t4 é B1 E t5 é B4 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é B4 com grau 0.178471907383
# SE t8 é B4 E t9 é B2 E t6 é B3 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0518616895354
# SE t8 é B4 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B2 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.0458051228113
# SE t8 é B3 E t9 é B1 E t6 é CE E t7 é B4 E t4 é S1 E t5 é B6 E t2 é CE E t3 é B6 E t1 é B4 ENTÃO t0 é B1 com grau 0.122829320556
# SE t8 é B6 E t9 é S1 E t6 é B5 E t7 é CE E t4 é B4 E t5 é B1 E t2 é B3 E t3 é B2 E t1 é B2 ENTÃO t0 é B2 com grau 0.17375012136
# SE t8 é B1 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B5 E t5 é B2 E t2 é B2 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.0866122980809
# SE t8 é B3 E t9 é B4 E t6 é B5 E t7 é B5 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B5 E t1 é B4 ENTÃO t0 é B5 com grau 0.109045797253
# SE t8 é B3 E t9 é B2 E t6 é B5 E t7 é B2 E t4 é B2 E t5 é B1 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.123715726226
# SE t8 é B3 E t9 é B3 E t6 é B2 E t7 é B4 E t4 é B1 E t5 é B4 E t2 é B2 E t3 é B5 E t1 é B3 ENTÃO t0 é B5 com grau 0.094296694096
# SE t8 é B2 E t9 é B2 E t6 é B1 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B4 E t3 é B2 E t1 é B2 ENTÃO t0 é B5 com grau 0.0285394144962
# SE t8 é B3 E t9 é B4 E t6 é B4 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B2 ENTÃO t0 é B4 com grau 0.0575557339912
# SE t8 é B5 E t9 é B1 E t6 é B3 E t7 é B2 E t4 é CE E t5 é B5 E t2 é B2 E t3 é B5 E t1 é B3 ENTÃO t0 é B4 com grau 0.0731614212495
# SE t8 é B4 E t9 é B1 E t6 é B4 E t7 é B1 E t4 é B2 E t5 é B3 E t2 é B1 E t3 é B4 E t1 é B5 ENTÃO t0 é B1 com grau 0.0543179671474
# SE t8 é B4 E t9 é B1 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B2 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B4 com grau 0.086792171684
# SE t8 é B1 E t9 é B5 E t6 é B2 E t7 é B5 E t4 é B2 E t5 é B3 E t2 é B2 E t3 é B3 E t1 é B5 ENTÃO t0 é B1 com grau 0.170291355843
# SE t8 é B4 E t9 é B2 E t6 é B5 E t7 é B2 E t4 é B6 E t5 é CE E t2 é B4 E t3 é CE E t1 é B2 ENTÃO t0 é B4 com grau 0.0512679206736
# SE t8 é B6 E t9 é CE E t6 é B5 E t7 é B1 E t4 é B6 E t5 é S1 E t2 é B5 E t3 é CE E t1 é B1 ENTÃO t0 é B4 com grau 0.0633521931221
# SE t8 é B3 E t9 é B2 E t6 é B2 E t7 é B3 E t4 é B2 E t5 é B3 E t2 é B1 E t3 é B5 E t1 é B5 ENTÃO t0 é CE com grau 0.0660273915027
# SE t8 é B5 E t9 é B3 E t6 é B4 E t7 é B2 E t4 é B3 E t5 é B3 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.112919012296
# SE t8 é B3 E t9 é B4 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B2 E t2 é B1 E t3 é B5 E t1 é B3 ENTÃO t0 é B4 com grau 0.0657723051013
# SE t8 é B3 E t9 é B3 E t6 é B10 E t7 é CE E t4 é B3 E t5 é S10 E t2 é B4 E t3 é B2 E t1 é S1 ENTÃO t0 é B4 com grau 0.0348556790688
# SE t8 é B3 E t9 é B3 E t6 é B1 E t7 é B4 E t4 é B3 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.0396125175521
# SE t8 é B3 E t9 é B5 E t6 é B5 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B3 E t1 é B5 ENTÃO t0 é B3 com grau 0.0687426669185
# SE t8 é CE E t9 é B6 E t6 é S1 E t7 é B5 E t4 é B4 E t5 é B4 E t2 é B3 E t3 é B1 E t1 é B2 ENTÃO t0 é B4 com grau 0.164762527202
# SE t8 é B2 E t9 é B5 E t6 é B3 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B3 E t3 é B3 E t1 é B3 ENTÃO t0 é B4 com grau 0.152317938263
# SE t8 é B2 E t9 é B5 E t6 é B2 E t7 é B3 E t4 é CE E t5 é B5 E t2 é B1 E t3 é B5 E t1 é B3 ENTÃO t0 é B4 com grau 0.116676085431
# SE t8 é B3 E t9 é B2 E t6 é B2 E t7 é B3 E t4 é B3 E t5 é B4 E t2 é B2 E t3 é B3 E t1 é B4 ENTÃO t0 é B2 com grau 0.0920378141155
# SE t8 é B3 E t9 é B4 E t6 é B3 E t7 é B2 E t4 é B2 E t5 é B3 E t2 é B2 E t3 é B5 E t1 é B3 ENTÃO t0 é B2 com grau 0.0120074581006
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.0563368902146
# SE t8 é B3 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B4 E t1 é B4 ENTÃO t0 é B3 com grau 0.0170987372158
# SE t8 é B5 E t9 é B1 E t6 é B2 E t7 é B2 E t4 é B2 E t5 é B4 E t2 é B1 E t3 é B4 E t1 é B6 ENTÃO t0 é S1 com grau 0.0903082505169
# SE t8 é B5 E t9 é B1 E t6 é B6 E t7 é S1 E t4 é B5 E t5 é CE E t2 é B4 E t3 é B1 E t1 é B2 ENTÃO t0 é B3 com grau 0.0599453884876
# SE t8 é B1 E t9 é B5 E t6 é B2 E t7 é B5 E t4 é B1 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.0277003297449
# SE t8 é S1 E t9 é B5 E t6 é CE E t7 é B6 E t4 é B1 E t5 é B5 E t2 é B2 E t3 é B4 E t1 é B3 ENTÃO t0 é B2 com grau 0.0932553068488
# SE t8 é B4 E t9 é B3 E t6 é B4 E t7 é B1 E t4 é B3 E t5 é B2 E t2 é B3 E t3 é B4 E t1 é B1 ENTÃO t0 é B6 com grau 0.0504611027509
# SE t8 é B5 E t9 é B4 E t6 é B4 E t7 é B4 E t4 é B3 E t5 é B5 E t2 é B5 E t3 é B4 E t1 é B3 ENTÃO t0 é B4 com grau 0.0373085348672
# SE t8 é CE E t9 é B6 E t6 é B1 E t7 é B6 E t4 é S1 E t5 é B5 E t2 é CE E t3 é B6 E t1 é B5 ENTÃO t0 é B1 com grau 0.0795592690415
# SE t8 é B4 E t9 é B1 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B3 E t2 é B5 E t3 é B1 E t1 é B2 ENTÃO t0 é B4 com grau 0.0416973661492
# SE t8 é B3 E t9 é B2 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B2 E t2 é B5 E t3 é B1 E t1 é B2 ENTÃO t0 é B5 com grau 0.0871514978761
# SE t8 é B4 E t9 é B2 E t6 é B2 E t7 é B4 E t4 é B2 E t5 é B5 E t2 é B3 E t3 é B3 E t1 é B2 ENTÃO t0 é B4 com grau 0.0390108290184
# SE t8 é B3 E t9 é B3 E t6 é B2 E t7 é B3 E t4 é B1 E t5 é B4 E t2 é B2 E t3 é B5 E t1 é B5 ENTÃO t0 é B1 com grau 0.111209228738
# SE t8 é B10 E t9 é S1 E t6 é B1 E t7 é B5 E t4 é B2 E t5 é B4 E t2 é B3 E t3 é B3 E t1 é B2 ENTÃO t0 é B3 com grau 0.0709909332185
# SE t8 é B2 E t9 é B4 E t6 é B2 E t7 é B5 E t4 é B3 E t5 é B3 E t2 é B4 E t3 é B2 E t1 é B3 ENTÃO t0 é B3 com grau 0.0508836492078
# SE t8 é B4 E t9 é B1 E t6 é B1 E t7 é B3 E t4 é B1 E t5 é B5 E t2 é B3 E t3 é B4 E t1 é B2 ENTÃO t0 é B4 com grau 0.150129883855
# SE t8 é B2 E t9 é B4 E t6 é B2 E t7 é B4 E t4 é B1 E t5 é B4 E t2 é B3 E t3 é B4 E t1 é B2 ENTÃO t0 é B3 com grau 0.017429634387
# SE t8 é B4 E t9 é CE E t6 é B1 E t7 é B3 E t4 é CE E t5 é B6 E t2 é B2 E t3 é B5 E t1 é B2 ENTÃO t0 é B5 com grau 0.0541644711734
# SE t8 é B2 E t9 é B3 E t6 é B5 E t7 é B3 E t4 é B3 E t5 é B1 E t2 é B1 E t3 é B4 E t1 é B5 ENTÃO t0 é B2 com grau 0.0645404031588
# SE t8 é B3 E t9 é B4 E t6 é B3 E t7 é B4 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B3 E t1 é B4 ENTÃO t0 é B4 com grau 0.104527838855
# SE t8 é B4 E t9 é B3 E t6 é B3 E t7 é B3 E t4 é B4 E t5 é B5 E t2 é B3 E t3 é B4 E t1 é B4 ENTÃO t0 é B4 com grau 0.0822367004526
# SE t8 é B4 E t9 é B2 E t6 é B5 E t7 é CE E t4 é B3 E t5 é B2 E t2 é B6 E t3 é B1 E t1 é CE ENTÃO t0 é B4 com grau 0.0551040313444
# SE t8 é CE E t9 é B5 E t6 é B2 E t7 é B5 E t4 é B4 E t5 é B3 E t2 é B4 E t3 é B2 E t1 é B2 ENTÃO t0 é B4 com grau 0.0529532548303
# SE t8 é B3 E t9 é B2 E t6 é B6 E t7 é B1 E t4 é B4 E t5 é CE E t2 é B3 E t3 é B2 E t1 é B3 ENTÃO t0 é B1 com grau 0.0773963735527
# SE t8 é B4 E t9 é B3 E t6 é B2 E t7 é B3 E t4 é B3 E t5 é B5 E t2 é B3 E t3 é B3 E t1 é B4 ENTÃO t0 é B2 com grau 0.0891138157192
# SE t8 é B2 E t9 é B3 E t6 é B5 E t7 é B2 E t4 é B5 E t5 é CE E t2 é B2 E t3 é B2 E t1 é B3 ENTÃO t0 é B4 com grau 0.0876947110504
# SE t8 é B3 E t9 é B3 E t6 é B2 E t7 é B5 E t4 é B3 E t5 é B4 E t2 é B4 E t3 é B3 E t1 é B3 ENTÃO t0 é B3 com grau 0.147521015903
# SE t8 é B5 E t9 é B3 E t6 é B3 E t7 é B1 E t4 é B1 E t5 é B4 E t2 é B2 E t3 é B5 E t1 é B2 ENTÃO t0 é B4 com grau 0.0747516647218
# SE t8 é B1 E t9 é B4 E t6 é B5 E t7 é B3 E t4 é B10 E t5 é S1 E t2 é B1 E t3 é B5 E t1 é B4 ENTÃO t0 é B2 com grau 0.0387254530751
# SE t8 é CE E t9 é B5 E t6 é CE E t7 é B6 E t4 é B2 E t5 é B4 E t2 é B2 E t3 é B4 E t1 é B3 ENTÃO t0 é B3 com grau 0.119243692141
# SE t8 é B4 E t9 é B2 E t6 é B4 E t7 é B1 E t4 é B2 E t5 é B3 E t2 é B2 E t3 é B4 E t1 é B5 ENTÃO t0 é CE com grau 0.0355017854658

# %%
zz = []
for t in range(10,len(ts)):
    ii = {'t0':0}
    for ic in range(9,0,-1):
        ii['t'+str(ic)] = ts[t-ic]
    tmp = defuzzy_rule(ii,['t'+str(xx) for xx in range(9,0,-1)],'t0',conj6,reg6)
    ii['t0'] = tmp
    zz.append(tmp)

# %%
fig = plt.figure(figsize=[20,6])
plt.ylabel('z(t)')
plt.xlabel('t')
po, = plot(ts,color='b',label='Original')
pp, = plot(zz,color='r',label='Prevista')
plt.legend(handles=[po,pp])
fig.show()
